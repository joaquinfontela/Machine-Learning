# %% [markdown]
# # NEURONAL LINKS😎️

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.ticker as ticker
import seaborn as sns
from sklearn.datasets import load_boston
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ParameterGrid
from sklearn.inspection import permutation_importance
import multiprocessing

# %%
labels = pd.read_csv('../../csv/train_labels.csv')
labels.head()
# Out:
#    building_id  damage_grade
# 0       802906             3
# 1        28830             2
# 2        94947             3
# 3       590882             2
# 4       201944             3

# %%
values = pd.read_csv('../../csv/train_values.csv')
values.T
# Out:
#                                         0      1      2       3       4       \
# building_id                             802906  28830  94947  590882  201944
# geo_level_1_id                               6      8     21      22      11
# geo_level_2_id                             487    900    363     418     131
# geo_level_3_id                           12198   2812   8973   10694    1488
# count_floors_pre_eq                          2      2      2       2       3
# age                                         30     10     10      10      30
# area_percentage                              6      8      5       6       8
# height_percentage                            5      7      5       5       9
# land_surface_condition                       t      o      t       t       t
# foundation_type                              r      r      r       r       r
# roof_type                                    n      n      n       n       n
# ground_floor_type                            f      x      f       f       f
# other_floor_type                             q      q      x       x       x
# position                                     t      s      t       s       s
# plan_configuration                           d      d      d       d       d
# has_superstructure_adobe_mud                 1      0      0       0       1
# has_superstructure_mud_mortar_stone          1      1      1       1       0
# has_superstructure_stone_flag                0      0      0       0       0
# has_superstructure_cement_mortar_stone       0      0      0       0       0
# has_superstructure_mud_mortar_brick          0      0      0       0       0
# has_superstructure_cement_mortar_brick       0      0      0       0       0
# has_superstructure_timber                    0      0      0       1       0
# has_superstructure_bamboo                    0      0      0       1       0
# has_superstructure_rc_non_engineered         0      0      0       0       0
# has_superstructure_rc_engineered             0      0      0       0       0
# has_superstructure_other                     0      0      0       0       0
# legal_ownership_status                       v      v      v       v       v
# count_families                               1      1      1       1       1
# has_secondary_use                            0      0      0       0       0
# has_secondary_use_agriculture                0      0      0       0       0
# has_secondary_use_hotel                      0      0      0       0       0
# has_secondary_use_rental                     0      0      0       0       0
# has_secondary_use_institution                0      0      0       0       0
# has_secondary_use_school                     0      0      0       0       0
# has_secondary_use_industry                   0      0      0       0       0
# has_secondary_use_health_post                0      0      0       0       0
# has_secondary_use_gov_office                 0      0      0       0       0
# has_secondary_use_use_police                 0      0      0       0       0
# has_secondary_use_other                      0      0      0       0       0
#
#                                         5       6       7       8       \
# building_id                             333020  728451  475515  441126
# geo_level_1_id                               8       9      20       0
# geo_level_2_id                             558     475     323     757
# geo_level_3_id                            6089   12066   12236    7219
# count_floors_pre_eq                          2       2       2       2
# age                                         10      25       0      15
# area_percentage                              9       3       8       8
# height_percentage                            5       4       6       6
# land_surface_condition                       t       n       t       t
# foundation_type                              r       r       w       r
# roof_type                                    n       n       q       q
# ground_floor_type                            f       x       v       f
# other_floor_type                             q       q       x       q
# position                                     s       s       s       s
# plan_configuration                           d       d       u       d
# has_superstructure_adobe_mud                 0       0       0       0
# has_superstructure_mud_mortar_stone          1       1       0       1
# has_superstructure_stone_flag                0       0       0       0
# has_superstructure_cement_mortar_stone       0       0       0       0
# has_superstructure_mud_mortar_brick          0       0       0       0
# has_superstructure_cement_mortar_brick       0       0       1       0
# has_superstructure_timber                    0       0       1       1
# has_superstructure_bamboo                    0       0       0       0
# has_superstructure_rc_non_engineered         0       0       0       0
# has_superstructure_rc_engineered             0       0       0       0
# has_superstructure_other                     0       0       0       0
# legal_ownership_status                       v       v       v       v
# count_families                               1       1       1       1
# has_secondary_use                            1       0       0       0
# has_secondary_use_agriculture                1       0       0       0
# has_secondary_use_hotel                      0       0       0       0
# has_secondary_use_rental                     0       0       0       0
# has_secondary_use_institution                0       0       0       0
# has_secondary_use_school                     0       0       0       0
# has_secondary_use_industry                   0       0       0       0
# has_secondary_use_health_post                0       0       0       0
# has_secondary_use_gov_office                 0       0       0       0
# has_secondary_use_use_police                 0       0       0       0
# has_secondary_use_other                      0       0       0       0
#
#                                         9       ...  260591  260592  260593  \
# building_id                             989500  ...  560805  207683  226421
# geo_level_1_id                              26  ...      20      10       8
# geo_level_2_id                             886  ...     368    1382     767
# geo_level_3_id                             994  ...    5980    1903    8613
# count_floors_pre_eq                          1  ...       1       2       2
# age                                          0  ...      25      25       5
# area_percentage                             13  ...       5       5      13
# height_percentage                            4  ...       3       5       5
# land_surface_condition                       t  ...       n       t       t
# foundation_type                              i  ...       r       r       r
# roof_type                                    n  ...       n       n       n
# ground_floor_type                            v  ...       f       f       f
# other_floor_type                             j  ...       j       q       q
# position                                     s  ...       s       s       s
# plan_configuration                           d  ...       d       d       d
# has_superstructure_adobe_mud                 0  ...       0       0       0
# has_superstructure_mud_mortar_stone          0  ...       1       1       1
# has_superstructure_stone_flag                0  ...       0       0       0
# has_superstructure_cement_mortar_stone       0  ...       0       0       0
# has_superstructure_mud_mortar_brick          0  ...       0       0       0
# has_superstructure_cement_mortar_brick       1  ...       0       0       0
# has_superstructure_timber                    0  ...       0       1       0
# has_superstructure_bamboo                    0  ...       0       0       0
# has_superstructure_rc_non_engineered         0  ...       0       0       0
# has_superstructure_rc_engineered             0  ...       0       0       0
# has_superstructure_other                     0  ...       0       0       0
# legal_ownership_status                       v  ...       v       v       v
# count_families                               1  ...       1       1       1
# has_secondary_use                            0  ...       1       0       1
# has_secondary_use_agriculture                0  ...       1       0       1
# has_secondary_use_hotel                      0  ...       0       0       0
# has_secondary_use_rental                     0  ...       0       0       0
# has_secondary_use_institution                0  ...       0       0       0
# has_secondary_use_school                     0  ...       0       0       0
# has_secondary_use_industry                   0  ...       0       0       0
# has_secondary_use_health_post                0  ...       0       0       0
# has_secondary_use_gov_office                 0  ...       0       0       0
# has_secondary_use_use_police                 0  ...       0       0       0
# has_secondary_use_other                      0  ...       0       0       0
#
#                                         260594  260595  260596  260597  \
# building_id                             159555  827012  688636  669485
# geo_level_1_id                              27       8      25      17
# geo_level_2_id                             181     268    1335     715
# geo_level_3_id                            1537    4718    1621    2060
# count_floors_pre_eq                          6       2       1       2
# age                                          0      20      55       0
# area_percentage                             13       8       6       6
# height_percentage                           12       5       3       5
# land_surface_condition                       t       t       n       t
# foundation_type                              r       r       r       r
# roof_type                                    n       n       n       n
# ground_floor_type                            f       f       f       f
# other_floor_type                             x       q       j       q
# position                                     j       s       s       s
# plan_configuration                           d       d       q       d
# has_superstructure_adobe_mud                 0       0       0       0
# has_superstructure_mud_mortar_stone          0       1       1       1
# has_superstructure_stone_flag                0       0       0       0
# has_superstructure_cement_mortar_stone       0       0       0       0
# has_superstructure_mud_mortar_brick          1       0       0       0
# has_superstructure_cement_mortar_brick       0       0       0       0
# has_superstructure_timber                    0       0       0       0
# has_superstructure_bamboo                    0       0       0       0
# has_superstructure_rc_non_engineered         0       0       0       0
# has_superstructure_rc_engineered             0       0       0       0
# has_superstructure_other                     0       0       0       0
# legal_ownership_status                       v       v       v       v
# count_families                               1       1       1       1
# has_secondary_use                            0       0       0       0
# has_secondary_use_agriculture                0       0       0       0
# has_secondary_use_hotel                      0       0       0       0
# has_secondary_use_rental                     0       0       0       0
# has_secondary_use_institution                0       0       0       0
# has_secondary_use_school                     0       0       0       0
# has_secondary_use_industry                   0       0       0       0
# has_secondary_use_health_post                0       0       0       0
# has_secondary_use_gov_office                 0       0       0       0
# has_secondary_use_use_police                 0       0       0       0
# has_secondary_use_other                      0       0       0       0
#
#                                         260598  260599  260600
# building_id                             602512  151409  747594
# geo_level_1_id                              17      26      21
# geo_level_2_id                              51      39       9
# geo_level_3_id                            8163    1851    9101
# count_floors_pre_eq                          3       2       3
# age                                         55      10      10
# area_percentage                              6      14       7
# height_percentage                            7       6       6
# land_surface_condition                       t       t       n
# foundation_type                              r       r       r
# roof_type                                    q       x       n
# ground_floor_type                            f       v       f
# other_floor_type                             q       s       q
# position                                     s       j       j
# plan_configuration                           d       d       d
# has_superstructure_adobe_mud                 0       0       0
# has_superstructure_mud_mortar_stone          1       0       1
# has_superstructure_stone_flag                0       0       0
# has_superstructure_cement_mortar_stone       0       0       0
# has_superstructure_mud_mortar_brick          0       0       0
# has_superstructure_cement_mortar_brick       0       1       0
# has_superstructure_timber                    0       0       0
# has_superstructure_bamboo                    0       0       0
# has_superstructure_rc_non_engineered         0       0       0
# has_superstructure_rc_engineered             0       0       0
# has_superstructure_other                     0       0       0
# legal_ownership_status                       v       v       v
# count_families                               1       1       3
# has_secondary_use                            0       0       0
# has_secondary_use_agriculture                0       0       0
# has_secondary_use_hotel                      0       0       0
# has_secondary_use_rental                     0       0       0
# has_secondary_use_institution                0       0       0
# has_secondary_use_school                     0       0       0
# has_secondary_use_industry                   0       0       0
# has_secondary_use_health_post                0       0       0
# has_secondary_use_gov_office                 0       0       0
# has_secondary_use_use_police                 0       0       0
# has_secondary_use_other                      0       0       0
#
# [39 rows x 260601 columns]

# %%
values["building_id"].count() == values["building_id"].drop_duplicates().count()
# Out:
# True

# %%
to_be_categorized = ["land_surface_condition", "foundation_type", "roof_type",\
                     "position", "ground_floor_type", "other_floor_type",\
                     "plan_configuration", "legal_ownership_status"]
for row in to_be_categorized:
    values[row] = values[row].astype("category")

# %%
datatypes = dict(values.dtypes)
for row in values.columns:
    if datatypes[row] != "int64" and datatypes[row] != "int32" and \
       datatypes[row] != "int16" and datatypes[row] != "int8":
        continue
    if values[row].nlargest(1).item() > 32767 and values[row].nlargest(1).item() < 2**31:
        values[row] = values[row].astype(np.int32)
    elif values[row].nlargest(1).item() > 127:
        values[row] = values[row].astype(np.int16)
    else:
        values[row] = values[row].astype(np.int8)

# %%
labels["building_id"] = labels["building_id"].astype(np.int32)
labels["damage_grade"] = labels["damage_grade"].astype(np.int8)

# %%
important_values = values\
                .merge(labels, on="building_id")
important_values.drop(columns=["building_id"], inplace = True)
important_values["geo_level_1_id"] = important_values["geo_level_1_id"].astype("category")

# %%
X_train, X_test, y_train, y_test = train_test_split(important_values.drop(columns = 'damage_grade'),
                                                    important_values['damage_grade'], test_size = 0.2, random_state = 123)

# %%
def encode_and_bind(original_dataframe, feature_to_encode):
    dummies = pd.get_dummies(original_dataframe[[feature_to_encode]])
    res = pd.concat([original_dataframe, dummies], axis=1)
    res = res.drop([feature_to_encode], axis=1)
    return(res) 

features_to_encode = ["geo_level_1_id", "land_surface_condition", "foundation_type", "roof_type",\
                     "position", "ground_floor_type", "other_floor_type",\
                     "plan_configuration", "legal_ownership_status"]
for feature in features_to_encode:
    X_train = encode_and_bind(X_train, feature)
    X_test = encode_and_bind(X_test, feature)

# %%
import sklearn as sk
import sklearn.neural_network

# %%
neuronal = sk.neural_network.MLPClassifier(solver='adam', 
                                     activation = 'relu',
                                     learning_rate_init=0.001,
                                     learning_rate = 'adaptive',
                                     verbose=True,
                                     batch_size = 'auto')

neuronal.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 5.25474738
# Iteration 2, loss = 3.18594413
# Iteration 3, loss = 2.88469088
# Iteration 4, loss = 2.81965069
# Iteration 5, loss = 2.44552548
# Iteration 6, loss = 2.51948746
# Iteration 7, loss = 2.60433442
# Iteration 8, loss = 2.21060171
# Iteration 9, loss = 2.26547626
# Iteration 10, loss = 2.14678334
# Iteration 11, loss = 2.19980556
# Iteration 12, loss = 2.09647192
# Iteration 13, loss = 2.11160082
# Iteration 14, loss = 1.98182551
# Iteration 15, loss = 2.08564199
# Iteration 16, loss = 2.01294948
# Iteration 17, loss = 1.87938322
# Iteration 18, loss = 1.89419360
# Iteration 19, loss = 1.73249508
# Iteration 20, loss = 1.82456593
# Iteration 21, loss = 1.86037611
# Iteration 22, loss = 1.77363469
# Iteration 23, loss = 1.58876646
# Iteration 24, loss = 1.65221463
# Iteration 25, loss = 1.53940986
# Iteration 26, loss = 1.72265316
# Iteration 27, loss = 1.44076744
# Iteration 28, loss = 1.66661238
# Iteration 29, loss = 1.32615156
# Iteration 30, loss = 1.44589073
# Iteration 31, loss = 1.35390101
# Iteration 32, loss = 1.34286511
# Iteration 33, loss = 1.25546851
# Iteration 34, loss = 1.33409706
# Iteration 35, loss = 1.21677533
# Iteration 36, loss = 1.29040558
# Iteration 37, loss = 1.21785666
# Iteration 38, loss = 1.30403931
# Iteration 39, loss = 1.07653803
# Iteration 40, loss = 1.16079463
# Iteration 41, loss = 1.28330006
# Iteration 42, loss = 1.17232011
# Iteration 43, loss = 1.20161484
# Iteration 44, loss = 1.15312422
# Iteration 45, loss = 1.05156105
# Iteration 46, loss = 1.06149262
# Iteration 47, loss = 1.08864326
# Iteration 48, loss = 1.06586963
# Iteration 49, loss = 1.09246116
# Iteration 50, loss = 1.05752361
# Iteration 51, loss = 1.04240750
# Iteration 52, loss = 0.94128414
# Iteration 53, loss = 1.00019297
# Iteration 54, loss = 1.14314692
# Iteration 55, loss = 0.93319947
# Iteration 56, loss = 1.01525900
# Iteration 57, loss = 0.97186088
# Iteration 58, loss = 0.98851062
# Iteration 59, loss = 0.91188813
# Iteration 60, loss = 0.91098471
# Iteration 61, loss = 0.93060768
# Iteration 62, loss = 0.95805358
# Iteration 63, loss = 0.91299464
# Iteration 64, loss = 0.90415874
# Iteration 65, loss = 0.89256335
# Iteration 66, loss = 0.92514028
# Iteration 67, loss = 0.91807388
# Iteration 68, loss = 0.85035656
# Iteration 69, loss = 0.87530867
# Iteration 70, loss = 0.86292373
# Iteration 71, loss = 0.86456290
# Iteration 72, loss = 0.87555714
# Iteration 73, loss = 0.88609429
# Iteration 74, loss = 0.80558757
# Iteration 75, loss = 0.86422235
# Iteration 76, loss = 0.80606619
# Iteration 77, loss = 0.82812195
# Iteration 78, loss = 0.81166344
# Iteration 79, loss = 0.79956898
# Iteration 80, loss = 0.80367988
# Iteration 81, loss = 0.82714497
# Iteration 82, loss = 0.80845055
# Iteration 83, loss = 0.79536986
# Iteration 84, loss = 0.80055512
# Iteration 85, loss = 0.78107249
# Iteration 86, loss = 0.80417794
# Iteration 87, loss = 0.79719961
# Iteration 88, loss = 0.77817802
# Iteration 89, loss = 0.78170643
# Iteration 90, loss = 0.77301572
# Iteration 91, loss = 0.77902662
# Iteration 92, loss = 0.76375323
# Iteration 93, loss = 0.78996237
# Iteration 94, loss = 0.78073181
# Iteration 95, loss = 0.77284707
# Iteration 96, loss = 0.76681183
# Iteration 97, loss = 0.77863292
# Iteration 98, loss = 0.77020685
# Iteration 99, loss = 0.76411738
# Iteration 100, loss = 0.76310761
# Iteration 101, loss = 0.76096419
# Iteration 102, loss = 0.75607943
# Iteration 103, loss = 0.75996448
# Iteration 104, loss = 0.75773971
# Iteration 105, loss = 0.75864289
# Iteration 106, loss = 0.75474431
# Iteration 107, loss = 0.75552295
# Iteration 108, loss = 0.76076750
# Iteration 109, loss = 0.75549784
# Iteration 110, loss = 0.74839663
# Iteration 111, loss = 0.74915009
# Iteration 112, loss = 0.75065455
# Iteration 113, loss = 0.73959558
# Iteration 114, loss = 0.75163074
# Iteration 115, loss = 0.74214723
# Iteration 116, loss = 0.74775133
# Iteration 117, loss = 0.74940749
# Iteration 118, loss = 0.74226521
# Iteration 119, loss = 0.73583328
# Iteration 120, loss = 0.74027987
# Iteration 121, loss = 0.73838961
# Iteration 122, loss = 0.73655136
# Iteration 123, loss = 0.74044522
# Iteration 124, loss = 0.73363699
# Iteration 125, loss = 0.73612674
# Iteration 126, loss = 0.73469429
# Iteration 127, loss = 0.73353852
# Iteration 128, loss = 0.72760443
# Iteration 129, loss = 0.73107654
# Iteration 130, loss = 0.73306380
# Iteration 131, loss = 0.73402859
# Iteration 132, loss = 0.72704386
# Iteration 133, loss = 0.72745248
# Iteration 134, loss = 0.73147219
# Iteration 135, loss = 0.72984767
# Iteration 136, loss = 0.72837784
# Iteration 137, loss = 0.72369348
# Iteration 138, loss = 0.73083976
# Iteration 139, loss = 0.72393268
# Iteration 140, loss = 0.72616410
# Iteration 141, loss = 0.71826417
# Iteration 142, loss = 0.72370150
# Iteration 143, loss = 0.72278304
# Iteration 144, loss = 0.72051534
# Iteration 145, loss = 0.72041560
# Iteration 146, loss = 0.71864845
# Iteration 147, loss = 0.71851667
# Iteration 148, loss = 0.72410287
# Iteration 149, loss = 0.71813584
# Iteration 150, loss = 0.71787324
# Iteration 151, loss = 0.72031407
# Iteration 152, loss = 0.71648386
# Iteration 153, loss = 0.71689999
# Iteration 154, loss = 0.72209667
# Iteration 155, loss = 0.71459227
# Iteration 156, loss = 0.71394302
# Iteration 157, loss = 0.71532995
# Iteration 158, loss = 0.71449679
# Iteration 159, loss = 0.71326053
# Iteration 160, loss = 0.71256856
# Iteration 161, loss = 0.71099560
# Iteration 162, loss = 0.71490666
# Iteration 163, loss = 0.70907301
# Iteration 164, loss = 0.71224764
# Iteration 165, loss = 0.70964671
# Iteration 166, loss = 0.70924852
# Iteration 167, loss = 0.71044196
# Iteration 168, loss = 0.71028806
# Iteration 169, loss = 0.71014890
# Iteration 170, loss = 0.70740342
# Iteration 171, loss = 0.70764602
# Iteration 172, loss = 0.70630366
# Iteration 173, loss = 0.70393966
# Iteration 174, loss = 0.70542160
# Iteration 175, loss = 0.70604346
# Iteration 176, loss = 0.70630292
# Iteration 177, loss = 0.70563488
# Iteration 178, loss = 0.70617637
# Iteration 179, loss = 0.70499417
# Iteration 180, loss = 0.70490842
# Iteration 181, loss = 0.70387221
# Iteration 182, loss = 0.70378187
# Iteration 183, loss = 0.70574724
# Iteration 184, loss = 0.70394981
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(learning_rate='adaptive', verbose=True)

# %%
neuronal_pred = neuronal.predict(X_test)
f1_score(y_test, neuronal_pred, average='micro')
# Out:
# 0.6651637535734157

# %% [markdown]
# ni me guardo el csv imaginate lo malo que es
