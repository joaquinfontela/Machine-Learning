# %% [markdown]
# # LIGHT GBM

# %%
pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in /home/laucha/anaconda3/lib/python3.8/site-packages (3.2.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /home/laucha/anaconda3/lib/python3.8/site-packages (from lightgbm) (0.23.2)
# Requirement already satisfied: scipy in /home/laucha/anaconda3/lib/python3.8/site-packages (from lightgbm) (1.5.2)
# Requirement already satisfied: numpy in /home/laucha/anaconda3/lib/python3.8/site-packages (from lightgbm) (1.19.2)
# Requirement already satisfied: wheel in /home/laucha/anaconda3/lib/python3.8/site-packages (from lightgbm) (0.35.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/laucha/anaconda3/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/laucha/anaconda3/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm) (0.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.ticker as ticker
import seaborn as sns
from sklearn.datasets import load_boston
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ParameterGrid
from sklearn.inspection import permutation_importance
import multiprocessing
import lightgbm as lgb

# %%
labels = pd.read_csv('../../csv/train_labels.csv')
labels.head()
# Out:
#    building_id  damage_grade
# 0       802906             3
# 1        28830             2
# 2        94947             3
# 3       590882             2
# 4       201944             3

# %%
values = pd.read_csv('../../csv/train_values.csv')
values.T
# Out:
#                                         0      1      2       3       4       \
# building_id                             802906  28830  94947  590882  201944
# geo_level_1_id                               6      8     21      22      11
# geo_level_2_id                             487    900    363     418     131
# geo_level_3_id                           12198   2812   8973   10694    1488
# count_floors_pre_eq                          2      2      2       2       3
# age                                         30     10     10      10      30
# area_percentage                              6      8      5       6       8
# height_percentage                            5      7      5       5       9
# land_surface_condition                       t      o      t       t       t
# foundation_type                              r      r      r       r       r
# roof_type                                    n      n      n       n       n
# ground_floor_type                            f      x      f       f       f
# other_floor_type                             q      q      x       x       x
# position                                     t      s      t       s       s
# plan_configuration                           d      d      d       d       d
# has_superstructure_adobe_mud                 1      0      0       0       1
# has_superstructure_mud_mortar_stone          1      1      1       1       0
# has_superstructure_stone_flag                0      0      0       0       0
# has_superstructure_cement_mortar_stone       0      0      0       0       0
# has_superstructure_mud_mortar_brick          0      0      0       0       0
# has_superstructure_cement_mortar_brick       0      0      0       0       0
# has_superstructure_timber                    0      0      0       1       0
# has_superstructure_bamboo                    0      0      0       1       0
# has_superstructure_rc_non_engineered         0      0      0       0       0
# has_superstructure_rc_engineered             0      0      0       0       0
# has_superstructure_other                     0      0      0       0       0
# legal_ownership_status                       v      v      v       v       v
# count_families                               1      1      1       1       1
# has_secondary_use                            0      0      0       0       0
# has_secondary_use_agriculture                0      0      0       0       0
# has_secondary_use_hotel                      0      0      0       0       0
# has_secondary_use_rental                     0      0      0       0       0
# has_secondary_use_institution                0      0      0       0       0
# has_secondary_use_school                     0      0      0       0       0
# has_secondary_use_industry                   0      0      0       0       0
# has_secondary_use_health_post                0      0      0       0       0
# has_secondary_use_gov_office                 0      0      0       0       0
# has_secondary_use_use_police                 0      0      0       0       0
# has_secondary_use_other                      0      0      0       0       0
#
#                                         5       6       7       8       \
# building_id                             333020  728451  475515  441126
# geo_level_1_id                               8       9      20       0
# geo_level_2_id                             558     475     323     757
# geo_level_3_id                            6089   12066   12236    7219
# count_floors_pre_eq                          2       2       2       2
# age                                         10      25       0      15
# area_percentage                              9       3       8       8
# height_percentage                            5       4       6       6
# land_surface_condition                       t       n       t       t
# foundation_type                              r       r       w       r
# roof_type                                    n       n       q       q
# ground_floor_type                            f       x       v       f
# other_floor_type                             q       q       x       q
# position                                     s       s       s       s
# plan_configuration                           d       d       u       d
# has_superstructure_adobe_mud                 0       0       0       0
# has_superstructure_mud_mortar_stone          1       1       0       1
# has_superstructure_stone_flag                0       0       0       0
# has_superstructure_cement_mortar_stone       0       0       0       0
# has_superstructure_mud_mortar_brick          0       0       0       0
# has_superstructure_cement_mortar_brick       0       0       1       0
# has_superstructure_timber                    0       0       1       1
# has_superstructure_bamboo                    0       0       0       0
# has_superstructure_rc_non_engineered         0       0       0       0
# has_superstructure_rc_engineered             0       0       0       0
# has_superstructure_other                     0       0       0       0
# legal_ownership_status                       v       v       v       v
# count_families                               1       1       1       1
# has_secondary_use                            1       0       0       0
# has_secondary_use_agriculture                1       0       0       0
# has_secondary_use_hotel                      0       0       0       0
# has_secondary_use_rental                     0       0       0       0
# has_secondary_use_institution                0       0       0       0
# has_secondary_use_school                     0       0       0       0
# has_secondary_use_industry                   0       0       0       0
# has_secondary_use_health_post                0       0       0       0
# has_secondary_use_gov_office                 0       0       0       0
# has_secondary_use_use_police                 0       0       0       0
# has_secondary_use_other                      0       0       0       0
#
#                                         9       ...  260591  260592  260593  \
# building_id                             989500  ...  560805  207683  226421
# geo_level_1_id                              26  ...      20      10       8
# geo_level_2_id                             886  ...     368    1382     767
# geo_level_3_id                             994  ...    5980    1903    8613
# count_floors_pre_eq                          1  ...       1       2       2
# age                                          0  ...      25      25       5
# area_percentage                             13  ...       5       5      13
# height_percentage                            4  ...       3       5       5
# land_surface_condition                       t  ...       n       t       t
# foundation_type                              i  ...       r       r       r
# roof_type                                    n  ...       n       n       n
# ground_floor_type                            v  ...       f       f       f
# other_floor_type                             j  ...       j       q       q
# position                                     s  ...       s       s       s
# plan_configuration                           d  ...       d       d       d
# has_superstructure_adobe_mud                 0  ...       0       0       0
# has_superstructure_mud_mortar_stone          0  ...       1       1       1
# has_superstructure_stone_flag                0  ...       0       0       0
# has_superstructure_cement_mortar_stone       0  ...       0       0       0
# has_superstructure_mud_mortar_brick          0  ...       0       0       0
# has_superstructure_cement_mortar_brick       1  ...       0       0       0
# has_superstructure_timber                    0  ...       0       1       0
# has_superstructure_bamboo                    0  ...       0       0       0
# has_superstructure_rc_non_engineered         0  ...       0       0       0
# has_superstructure_rc_engineered             0  ...       0       0       0
# has_superstructure_other                     0  ...       0       0       0
# legal_ownership_status                       v  ...       v       v       v
# count_families                               1  ...       1       1       1
# has_secondary_use                            0  ...       1       0       1
# has_secondary_use_agriculture                0  ...       1       0       1
# has_secondary_use_hotel                      0  ...       0       0       0
# has_secondary_use_rental                     0  ...       0       0       0
# has_secondary_use_institution                0  ...       0       0       0
# has_secondary_use_school                     0  ...       0       0       0
# has_secondary_use_industry                   0  ...       0       0       0
# has_secondary_use_health_post                0  ...       0       0       0
# has_secondary_use_gov_office                 0  ...       0       0       0
# has_secondary_use_use_police                 0  ...       0       0       0
# has_secondary_use_other                      0  ...       0       0       0
#
#                                         260594  260595  260596  260597  \
# building_id                             159555  827012  688636  669485
# geo_level_1_id                              27       8      25      17
# geo_level_2_id                             181     268    1335     715
# geo_level_3_id                            1537    4718    1621    2060
# count_floors_pre_eq                          6       2       1       2
# age                                          0      20      55       0
# area_percentage                             13       8       6       6
# height_percentage                           12       5       3       5
# land_surface_condition                       t       t       n       t
# foundation_type                              r       r       r       r
# roof_type                                    n       n       n       n
# ground_floor_type                            f       f       f       f
# other_floor_type                             x       q       j       q
# position                                     j       s       s       s
# plan_configuration                           d       d       q       d
# has_superstructure_adobe_mud                 0       0       0       0
# has_superstructure_mud_mortar_stone          0       1       1       1
# has_superstructure_stone_flag                0       0       0       0
# has_superstructure_cement_mortar_stone       0       0       0       0
# has_superstructure_mud_mortar_brick          1       0       0       0
# has_superstructure_cement_mortar_brick       0       0       0       0
# has_superstructure_timber                    0       0       0       0
# has_superstructure_bamboo                    0       0       0       0
# has_superstructure_rc_non_engineered         0       0       0       0
# has_superstructure_rc_engineered             0       0       0       0
# has_superstructure_other                     0       0       0       0
# legal_ownership_status                       v       v       v       v
# count_families                               1       1       1       1
# has_secondary_use                            0       0       0       0
# has_secondary_use_agriculture                0       0       0       0
# has_secondary_use_hotel                      0       0       0       0
# has_secondary_use_rental                     0       0       0       0
# has_secondary_use_institution                0       0       0       0
# has_secondary_use_school                     0       0       0       0
# has_secondary_use_industry                   0       0       0       0
# has_secondary_use_health_post                0       0       0       0
# has_secondary_use_gov_office                 0       0       0       0
# has_secondary_use_use_police                 0       0       0       0
# has_secondary_use_other                      0       0       0       0
#
#                                         260598  260599  260600
# building_id                             602512  151409  747594
# geo_level_1_id                              17      26      21
# geo_level_2_id                              51      39       9
# geo_level_3_id                            8163    1851    9101
# count_floors_pre_eq                          3       2       3
# age                                         55      10      10
# area_percentage                              6      14       7
# height_percentage                            7       6       6
# land_surface_condition                       t       t       n
# foundation_type                              r       r       r
# roof_type                                    q       x       n
# ground_floor_type                            f       v       f
# other_floor_type                             q       s       q
# position                                     s       j       j
# plan_configuration                           d       d       d
# has_superstructure_adobe_mud                 0       0       0
# has_superstructure_mud_mortar_stone          1       0       1
# has_superstructure_stone_flag                0       0       0
# has_superstructure_cement_mortar_stone       0       0       0
# has_superstructure_mud_mortar_brick          0       0       0
# has_superstructure_cement_mortar_brick       0       1       0
# has_superstructure_timber                    0       0       0
# has_superstructure_bamboo                    0       0       0
# has_superstructure_rc_non_engineered         0       0       0
# has_superstructure_rc_engineered             0       0       0
# has_superstructure_other                     0       0       0
# legal_ownership_status                       v       v       v
# count_families                               1       1       3
# has_secondary_use                            0       0       0
# has_secondary_use_agriculture                0       0       0
# has_secondary_use_hotel                      0       0       0
# has_secondary_use_rental                     0       0       0
# has_secondary_use_institution                0       0       0
# has_secondary_use_school                     0       0       0
# has_secondary_use_industry                   0       0       0
# has_secondary_use_health_post                0       0       0
# has_secondary_use_gov_office                 0       0       0
# has_secondary_use_use_police                 0       0       0
# has_secondary_use_other                      0       0       0
#
# [39 rows x 260601 columns]

# %%
values["building_id"].count() == values["building_id"].drop_duplicates().count()
# Out:
# True

# %%
to_be_categorized = ["land_surface_condition", "foundation_type", "roof_type",\
                     "position", "ground_floor_type", "other_floor_type",\
                     "plan_configuration", "legal_ownership_status"]
for row in to_be_categorized:
    values[row] = values[row].astype("category")

# %%
datatypes = dict(values.dtypes)
for row in values.columns:
    if datatypes[row] != "int64" and datatypes[row] != "int32" and \
       datatypes[row] != "int16" and datatypes[row] != "int8":
        continue
    if values[row].nlargest(1).item() > 32767 and values[row].nlargest(1).item() < 2**31:
        values[row] = values[row].astype(np.int32)
    elif values[row].nlargest(1).item() > 127:
        values[row] = values[row].astype(np.int16)
    else:
        values[row] = values[row].astype(np.int8)

# %%
labels["building_id"] = labels["building_id"].astype(np.int32)
labels["damage_grade"] = labels["damage_grade"].astype(np.int8)

# %%
important_values = values\
                .merge(labels, on="building_id")
important_values.drop(columns=["building_id"], inplace = True)
important_values["geo_level_1_id"] = important_values["geo_level_1_id"].astype("category")

# %%
X_train, X_test, y_train, y_test = train_test_split(important_values.drop(columns = 'damage_grade'),
                                                    important_values['damage_grade'], test_size = 0.2, random_state = 123)

# %%
from sklearn.utils import class_weight

classes_weights = class_weight.compute_sample_weight(
    class_weight='balanced',
    y=y_train
)

classes_weights
# Out:
# array([0.58539434, 0.58539434, 0.99663454, ..., 0.99663454, 0.99663454,
#        0.99663454])

# %%
def encode_and_bind(original_dataframe, feature_to_encode):
    dummies = pd.get_dummies(original_dataframe[[feature_to_encode]])
    res = pd.concat([original_dataframe, dummies], axis=1)
    res = res.drop([feature_to_encode], axis=1)
    return(res) 

features_to_encode = ["geo_level_1_id", "land_surface_condition", "foundation_type", "roof_type",\
                     "position", "ground_floor_type", "other_floor_type",\
                     "plan_configuration", "legal_ownership_status"]
for feature in features_to_encode:
    X_train = encode_and_bind(X_train, feature)
    X_test = encode_and_bind(X_test, feature)

# %%
clf = lgb.LGBMClassifier(boosting_type='gbdt', 
                         colsample_bytree=1.0,
                         importance_type='split', 
                         learning_rate=0.15,
                         max_depth=None,
                         n_estimators=1600, 
                         n_jobs=-1,
                         objective=None,
                         subsample=1.0, 
                         subsample_for_bin=200000, 
                         subsample_freq=0)
clf.fit(X_train, y_train, 
          categorical_feature=['geo_level_2_id', 'geo_level_3_id'],
          eval_set=(X_test,y_test))
# Out:
# /home/joaquinfontela/.local/lib/python3.8/site-packages/lightgbm/basic.py:1702: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# [1]	training's multi_logloss: 0.823158
# [2]	training's multi_logloss: 0.765915
# [3]	training's multi_logloss: 0.724897
# [4]	training's multi_logloss: 0.693808
# [5]	training's multi_logloss: 0.670002
# [6]	training's multi_logloss: 0.651011
# [7]	training's multi_logloss: 0.635238
# [8]	training's multi_logloss: 0.622154
# [9]	training's multi_logloss: 0.611386
# [10]	training's multi_logloss: 0.602172
# [11]	training's multi_logloss: 0.593967
# [12]	training's multi_logloss: 0.586932
# [13]	training's multi_logloss: 0.580345
# [14]	training's multi_logloss: 0.574754
# [15]	training's multi_logloss: 0.569643
# [16]	training's multi_logloss: 0.564869
# [17]	training's multi_logloss: 0.560232
# [18]	training's multi_logloss: 0.556157
# [19]	training's multi_logloss: 0.552144
# [20]	training's multi_logloss: 0.548349
# [21]	training's multi_logloss: 0.544923
# [22]	training's multi_logloss: 0.541755
# [23]	training's multi_logloss: 0.538693
# [24]	training's multi_logloss: 0.535738
# [25]	training's multi_logloss: 0.532977
# [26]	training's multi_logloss: 0.530231
# [27]	training's multi_logloss: 0.527999
# [28]	training's multi_logloss: 0.525684
# [29]	training's multi_logloss: 0.523243
# [30]	training's multi_logloss: 0.520978
# [31]	training's multi_logloss: 0.51907
# [32]	training's multi_logloss: 0.516987
# [33]	training's multi_logloss: 0.515058
# [34]	training's multi_logloss: 0.513065
# [35]	training's multi_logloss: 0.511349
# [36]	training's multi_logloss: 0.509439
# [37]	training's multi_logloss: 0.50778
# [38]	training's multi_logloss: 0.506266
# [39]	training's multi_logloss: 0.504655
# [40]	training's multi_logloss: 0.503079
# [41]	training's multi_logloss: 0.501511
# [42]	training's multi_logloss: 0.500113
# [43]	training's multi_logloss: 0.498764
# [44]	training's multi_logloss: 0.497442
# [45]	training's multi_logloss: 0.495981
# [46]	training's multi_logloss: 0.494674
# [47]	training's multi_logloss: 0.493337
# [48]	training's multi_logloss: 0.492204
# [49]	training's multi_logloss: 0.491114
# [50]	training's multi_logloss: 0.489805
# [51]	training's multi_logloss: 0.48863
# [52]	training's multi_logloss: 0.487422
# [53]	training's multi_logloss: 0.486301
# [54]	training's multi_logloss: 0.485154
# [55]	training's multi_logloss: 0.484127
# [56]	training's multi_logloss: 0.483198
# [57]	training's multi_logloss: 0.482081
# [58]	training's multi_logloss: 0.481054
# [59]	training's multi_logloss: 0.480037
# [60]	training's multi_logloss: 0.479146
# [61]	training's multi_logloss: 0.478102
# [62]	training's multi_logloss: 0.47724
# [63]	training's multi_logloss: 0.476241
# [64]	training's multi_logloss: 0.475389
# [65]	training's multi_logloss: 0.474577
# [66]	training's multi_logloss: 0.473681
# [67]	training's multi_logloss: 0.47282
# [68]	training's multi_logloss: 0.472152
# [69]	training's multi_logloss: 0.471238
# [70]	training's multi_logloss: 0.47025
# [71]	training's multi_logloss: 0.469264
# [72]	training's multi_logloss: 0.468479
# [73]	training's multi_logloss: 0.467718
# [74]	training's multi_logloss: 0.467018
# [75]	training's multi_logloss: 0.466263
# [76]	training's multi_logloss: 0.465436
# [77]	training's multi_logloss: 0.46466
# [78]	training's multi_logloss: 0.464059
# [79]	training's multi_logloss: 0.463368
# [80]	training's multi_logloss: 0.462603
# [81]	training's multi_logloss: 0.461862
# [82]	training's multi_logloss: 0.461202
# [83]	training's multi_logloss: 0.460444
# [84]	training's multi_logloss: 0.459826
# [85]	training's multi_logloss: 0.459167
# [86]	training's multi_logloss: 0.458535
# [87]	training's multi_logloss: 0.458004
# [88]	training's multi_logloss: 0.457572
# [89]	training's multi_logloss: 0.456914
# [90]	training's multi_logloss: 0.456476
# [91]	training's multi_logloss: 0.455802
# [92]	training's multi_logloss: 0.455008
# [93]	training's multi_logloss: 0.454369
# [94]	training's multi_logloss: 0.453643
# [95]	training's multi_logloss: 0.453156
# [96]	training's multi_logloss: 0.452519
# [97]	training's multi_logloss: 0.452043
# [98]	training's multi_logloss: 0.451629
# [99]	training's multi_logloss: 0.451245
# [100]	training's multi_logloss: 0.450645
# [101]	training's multi_logloss: 0.450096
# [102]	training's multi_logloss: 0.449616
# [103]	training's multi_logloss: 0.4491
# [104]	training's multi_logloss: 0.448511
# [105]	training's multi_logloss: 0.44813
# [106]	training's multi_logloss: 0.447768
# [107]	training's multi_logloss: 0.447198
# [108]	training's multi_logloss: 0.44682
# [109]	training's multi_logloss: 0.446309
# [110]	training's multi_logloss: 0.445776
# [111]	training's multi_logloss: 0.445408
# [112]	training's multi_logloss: 0.44508
# [113]	training's multi_logloss: 0.444602
# [114]	training's multi_logloss: 0.444245
# [115]	training's multi_logloss: 0.443796
# [116]	training's multi_logloss: 0.443386
# [117]	training's multi_logloss: 0.442745
# [118]	training's multi_logloss: 0.442349
# [119]	training's multi_logloss: 0.441795
# [120]	training's multi_logloss: 0.441344
# [121]	training's multi_logloss: 0.440974
# [122]	training's multi_logloss: 0.440666
# [123]	training's multi_logloss: 0.440365
# [124]	training's multi_logloss: 0.439814
# [125]	training's multi_logloss: 0.439358
# [126]	training's multi_logloss: 0.438935
# [127]	training's multi_logloss: 0.438549
# [128]	training's multi_logloss: 0.438212
# [129]	training's multi_logloss: 0.437751
# [130]	training's multi_logloss: 0.437486
# [131]	training's multi_logloss: 0.437169
# [132]	training's multi_logloss: 0.436839
# [133]	training's multi_logloss: 0.436554
# [134]	training's multi_logloss: 0.436128
# [135]	training's multi_logloss: 0.43574
# [136]	training's multi_logloss: 0.435378
# [137]	training's multi_logloss: 0.435032
# [138]	training's multi_logloss: 0.434741
# [139]	training's multi_logloss: 0.434477
# [140]	training's multi_logloss: 0.434244
# [141]	training's multi_logloss: 0.433989
# [142]	training's multi_logloss: 0.433556
# [143]	training's multi_logloss: 0.433016
# [144]	training's multi_logloss: 0.432737
# [145]	training's multi_logloss: 0.432469
# [146]	training's multi_logloss: 0.432136
# [147]	training's multi_logloss: 0.431834
# [148]	training's multi_logloss: 0.431608
# [149]	training's multi_logloss: 0.431368
# [150]	training's multi_logloss: 0.431033
# [151]	training's multi_logloss: 0.430785
# [152]	training's multi_logloss: 0.430505
# [153]	training's multi_logloss: 0.430221
# [154]	training's multi_logloss: 0.429971
# [155]	training's multi_logloss: 0.429673
# [156]	training's multi_logloss: 0.429272
# [157]	training's multi_logloss: 0.429112
# [158]	training's multi_logloss: 0.428859
# [159]	training's multi_logloss: 0.428535
# [160]	training's multi_logloss: 0.428118
# [161]	training's multi_logloss: 0.4278
# [162]	training's multi_logloss: 0.4275
# [163]	training's multi_logloss: 0.42724
# [164]	training's multi_logloss: 0.426961
# [165]	training's multi_logloss: 0.426772
# [166]	training's multi_logloss: 0.426431
# [167]	training's multi_logloss: 0.426216
# [168]	training's multi_logloss: 0.425994
# [169]	training's multi_logloss: 0.425574
# [170]	training's multi_logloss: 0.425248
# [171]	training's multi_logloss: 0.424882
# [172]	training's multi_logloss: 0.424633
# [173]	training's multi_logloss: 0.424428
# [174]	training's multi_logloss: 0.424142
# [175]	training's multi_logloss: 0.423907
# [176]	training's multi_logloss: 0.423613
# [177]	training's multi_logloss: 0.423409
# [178]	training's multi_logloss: 0.423232
# [179]	training's multi_logloss: 0.422967
# [180]	training's multi_logloss: 0.422694
# [181]	training's multi_logloss: 0.422442
# [182]	training's multi_logloss: 0.422244
# [183]	training's multi_logloss: 0.422003
# [184]	training's multi_logloss: 0.421624
# [185]	training's multi_logloss: 0.421458
# [186]	training's multi_logloss: 0.421284
# [187]	training's multi_logloss: 0.421011
# [188]	training's multi_logloss: 0.42087
# [189]	training's multi_logloss: 0.420635
# [190]	training's multi_logloss: 0.420363
# [191]	training's multi_logloss: 0.42022
# [192]	training's multi_logloss: 0.420083
# [193]	training's multi_logloss: 0.419884
# [194]	training's multi_logloss: 0.419714
# [195]	training's multi_logloss: 0.419585
# [196]	training's multi_logloss: 0.419431
# [197]	training's multi_logloss: 0.41927
# [198]	training's multi_logloss: 0.419111
# [199]	training's multi_logloss: 0.418888
# [200]	training's multi_logloss: 0.418634
# [201]	training's multi_logloss: 0.418266
# [202]	training's multi_logloss: 0.417948
# [203]	training's multi_logloss: 0.417747
# [204]	training's multi_logloss: 0.417567
# [205]	training's multi_logloss: 0.417404
# [206]	training's multi_logloss: 0.417124
# [207]	training's multi_logloss: 0.416802
# [208]	training's multi_logloss: 0.416585
# [209]	training's multi_logloss: 0.416393
# [210]	training's multi_logloss: 0.416255
# [211]	training's multi_logloss: 0.416061
# [212]	training's multi_logloss: 0.415924
# [213]	training's multi_logloss: 0.415803
# [214]	training's multi_logloss: 0.41555
# [215]	training's multi_logloss: 0.415419
# [216]	training's multi_logloss: 0.415239
# [217]	training's multi_logloss: 0.414904
# [218]	training's multi_logloss: 0.414641
# [219]	training's multi_logloss: 0.414486
# [220]	training's multi_logloss: 0.414132
# [221]	training's multi_logloss: 0.4138
# [222]	training's multi_logloss: 0.413605
# [223]	training's multi_logloss: 0.413459
# [224]	training's multi_logloss: 0.413343
# [225]	training's multi_logloss: 0.413169
# [226]	training's multi_logloss: 0.413006
# [227]	training's multi_logloss: 0.412869
# [228]	training's multi_logloss: 0.412715
# [229]	training's multi_logloss: 0.412572
# [230]	training's multi_logloss: 0.412308
# [231]	training's multi_logloss: 0.412149
# [232]	training's multi_logloss: 0.412007
# [233]	training's multi_logloss: 0.411744
# [234]	training's multi_logloss: 0.411624
# [235]	training's multi_logloss: 0.411305
# [236]	training's multi_logloss: 0.411184
# [237]	training's multi_logloss: 0.41104
# [238]	training's multi_logloss: 0.410908
# [239]	training's multi_logloss: 0.410778
# [240]	training's multi_logloss: 0.410543
# [241]	training's multi_logloss: 0.410434
# [242]	training's multi_logloss: 0.410207
# [243]	training's multi_logloss: 0.410088
# [244]	training's multi_logloss: 0.409977
# [245]	training's multi_logloss: 0.409861
# [246]	training's multi_logloss: 0.40954
# [247]	training's multi_logloss: 0.40939
# [248]	training's multi_logloss: 0.409251
# [249]	training's multi_logloss: 0.409104
# [250]	training's multi_logloss: 0.408975
# [251]	training's multi_logloss: 0.408817
# [252]	training's multi_logloss: 0.408614
# [253]	training's multi_logloss: 0.408496
# [254]	training's multi_logloss: 0.408349
# [255]	training's multi_logloss: 0.408224
# [256]	training's multi_logloss: 0.408099
# [257]	training's multi_logloss: 0.407955
# [258]	training's multi_logloss: 0.407809
# [259]	training's multi_logloss: 0.407697
# [260]	training's multi_logloss: 0.407486
# [261]	training's multi_logloss: 0.407346
# [262]	training's multi_logloss: 0.407177
# [263]	training's multi_logloss: 0.406887
# [264]	training's multi_logloss: 0.406779
# [265]	training's multi_logloss: 0.406674
# [266]	training's multi_logloss: 0.406537
# [267]	training's multi_logloss: 0.406399
# [268]	training's multi_logloss: 0.406199
# [269]	training's multi_logloss: 0.406097
# [270]	training's multi_logloss: 0.405765
# [271]	training's multi_logloss: 0.405669
# [272]	training's multi_logloss: 0.405545
# [273]	training's multi_logloss: 0.405416
# [274]	training's multi_logloss: 0.405217
# [275]	training's multi_logloss: 0.405091
# [276]	training's multi_logloss: 0.404979
# [277]	training's multi_logloss: 0.404807
# [278]	training's multi_logloss: 0.404685
# [279]	training's multi_logloss: 0.404573
# [280]	training's multi_logloss: 0.404447
# [281]	training's multi_logloss: 0.404363
# [282]	training's multi_logloss: 0.404208
# [283]	training's multi_logloss: 0.404021
# [284]	training's multi_logloss: 0.403899
# [285]	training's multi_logloss: 0.40378
# [286]	training's multi_logloss: 0.40346
# [287]	training's multi_logloss: 0.403354
# [288]	training's multi_logloss: 0.403092
# [289]	training's multi_logloss: 0.402979
# [290]	training's multi_logloss: 0.402869
# [291]	training's multi_logloss: 0.402775
# [292]	training's multi_logloss: 0.402572
# [293]	training's multi_logloss: 0.402449
# [294]	training's multi_logloss: 0.402349
# [295]	training's multi_logloss: 0.402233
# [296]	training's multi_logloss: 0.402079
# [297]	training's multi_logloss: 0.40185
# [298]	training's multi_logloss: 0.401741
# [299]	training's multi_logloss: 0.401638
# [300]	training's multi_logloss: 0.401493
# [301]	training's multi_logloss: 0.401381
# [302]	training's multi_logloss: 0.401282
# [303]	training's multi_logloss: 0.401047
# [304]	training's multi_logloss: 0.400945
# [305]	training's multi_logloss: 0.400779
# [306]	training's multi_logloss: 0.400678
# [307]	training's multi_logloss: 0.400574
# [308]	training's multi_logloss: 0.400469
# [309]	training's multi_logloss: 0.400364
# [310]	training's multi_logloss: 0.400255
# [311]	training's multi_logloss: 0.400122
# [312]	training's multi_logloss: 0.399923
# [313]	training's multi_logloss: 0.399796
# [314]	training's multi_logloss: 0.399622
# [315]	training's multi_logloss: 0.399524
# [316]	training's multi_logloss: 0.399405
# [317]	training's multi_logloss: 0.399273
# [318]	training's multi_logloss: 0.399128
# [319]	training's multi_logloss: 0.399038
# [320]	training's multi_logloss: 0.398937
# [321]	training's multi_logloss: 0.398827
# [322]	training's multi_logloss: 0.398657
# [323]	training's multi_logloss: 0.398573
# [324]	training's multi_logloss: 0.398421
# [325]	training's multi_logloss: 0.398274
# [326]	training's multi_logloss: 0.398158
# [327]	training's multi_logloss: 0.398029
# [328]	training's multi_logloss: 0.397924
# [329]	training's multi_logloss: 0.397815
# [330]	training's multi_logloss: 0.397717
# [331]	training's multi_logloss: 0.397601
# [332]	training's multi_logloss: 0.39746
# [333]	training's multi_logloss: 0.39722
# [334]	training's multi_logloss: 0.397102
# [335]	training's multi_logloss: 0.397004
# [336]	training's multi_logloss: 0.396902
# [337]	training's multi_logloss: 0.396798
# [338]	training's multi_logloss: 0.396659
# [339]	training's multi_logloss: 0.396529
# [340]	training's multi_logloss: 0.396413
# [341]	training's multi_logloss: 0.396295
# [342]	training's multi_logloss: 0.396077
# [343]	training's multi_logloss: 0.395975
# [344]	training's multi_logloss: 0.395893
# [345]	training's multi_logloss: 0.395789
# [346]	training's multi_logloss: 0.395681
# [347]	training's multi_logloss: 0.395592
# [348]	training's multi_logloss: 0.395489
# [349]	training's multi_logloss: 0.395383
# [350]	training's multi_logloss: 0.395224
# [351]	training's multi_logloss: 0.395114
# [352]	training's multi_logloss: 0.394954
# [353]	training's multi_logloss: 0.39485
# [354]	training's multi_logloss: 0.394746
# [355]	training's multi_logloss: 0.39466
# [356]	training's multi_logloss: 0.394461
# [357]	training's multi_logloss: 0.394328
# [358]	training's multi_logloss: 0.394197
# [359]	training's multi_logloss: 0.394101
# [360]	training's multi_logloss: 0.393994
# [361]	training's multi_logloss: 0.393882
# [362]	training's multi_logloss: 0.393796
# [363]	training's multi_logloss: 0.393709
# [364]	training's multi_logloss: 0.393601
# [365]	training's multi_logloss: 0.3935
# [366]	training's multi_logloss: 0.393416
# [367]	training's multi_logloss: 0.393184
# [368]	training's multi_logloss: 0.393098
# [369]	training's multi_logloss: 0.392999
# [370]	training's multi_logloss: 0.392913
# [371]	training's multi_logloss: 0.39281
# [372]	training's multi_logloss: 0.392698
# [373]	training's multi_logloss: 0.392608
# [374]	training's multi_logloss: 0.392511
# [375]	training's multi_logloss: 0.392347
# [376]	training's multi_logloss: 0.392221
# [377]	training's multi_logloss: 0.392125
# [378]	training's multi_logloss: 0.392008
# [379]	training's multi_logloss: 0.391898
# [380]	training's multi_logloss: 0.391755
# [381]	training's multi_logloss: 0.391661
# [382]	training's multi_logloss: 0.391561
# [383]	training's multi_logloss: 0.39142
# [384]	training's multi_logloss: 0.391289
# [385]	training's multi_logloss: 0.391127
# [386]	training's multi_logloss: 0.391041
# [387]	training's multi_logloss: 0.390941
# [388]	training's multi_logloss: 0.390828
# [389]	training's multi_logloss: 0.390706
# [390]	training's multi_logloss: 0.390598
# [391]	training's multi_logloss: 0.39047
# [392]	training's multi_logloss: 0.39039
# [393]	training's multi_logloss: 0.390308
# [394]	training's multi_logloss: 0.390227
# [395]	training's multi_logloss: 0.390137
# [396]	training's multi_logloss: 0.390033
# [397]	training's multi_logloss: 0.389907
# [398]	training's multi_logloss: 0.389786
# [399]	training's multi_logloss: 0.389698
# [400]	training's multi_logloss: 0.389602
# [401]	training's multi_logloss: 0.389455
# [402]	training's multi_logloss: 0.389359
# [403]	training's multi_logloss: 0.389241
# [404]	training's multi_logloss: 0.389151
# [405]	training's multi_logloss: 0.389067
# [406]	training's multi_logloss: 0.388968
# [407]	training's multi_logloss: 0.388878
# [408]	training's multi_logloss: 0.388755
# [409]	training's multi_logloss: 0.388635
# [410]	training's multi_logloss: 0.388547
# [411]	training's multi_logloss: 0.388468
# [412]	training's multi_logloss: 0.388339
# [413]	training's multi_logloss: 0.388261
# [414]	training's multi_logloss: 0.388184
# [415]	training's multi_logloss: 0.388096
# [416]	training's multi_logloss: 0.388027
# [417]	training's multi_logloss: 0.387953
# [418]	training's multi_logloss: 0.387848
# [419]	training's multi_logloss: 0.387683
# [420]	training's multi_logloss: 0.387603
# [421]	training's multi_logloss: 0.387524
# [422]	training's multi_logloss: 0.387346
# [423]	training's multi_logloss: 0.387258
# [424]	training's multi_logloss: 0.387174
# [425]	training's multi_logloss: 0.387089
# [426]	training's multi_logloss: 0.387009
# [427]	training's multi_logloss: 0.386877
# [428]	training's multi_logloss: 0.386702
# [429]	training's multi_logloss: 0.386577
# [430]	training's multi_logloss: 0.386424
# [431]	training's multi_logloss: 0.386345
# [432]	training's multi_logloss: 0.386261
# [433]	training's multi_logloss: 0.386155
# [434]	training's multi_logloss: 0.386061
# [435]	training's multi_logloss: 0.385977
# [436]	training's multi_logloss: 0.38586
# [437]	training's multi_logloss: 0.385765
# [438]	training's multi_logloss: 0.38569
# [439]	training's multi_logloss: 0.385507
# [440]	training's multi_logloss: 0.385412
# [441]	training's multi_logloss: 0.385339
# [442]	training's multi_logloss: 0.385248
# [443]	training's multi_logloss: 0.385172
# [444]	training's multi_logloss: 0.385092
# [445]	training's multi_logloss: 0.384948
# [446]	training's multi_logloss: 0.384812
# [447]	training's multi_logloss: 0.384709
# [448]	training's multi_logloss: 0.384581
# [449]	training's multi_logloss: 0.384459
# [450]	training's multi_logloss: 0.384361
# [451]	training's multi_logloss: 0.384258
# [452]	training's multi_logloss: 0.384159
# [453]	training's multi_logloss: 0.384008
# [454]	training's multi_logloss: 0.383933
# [455]	training's multi_logloss: 0.383822
# [456]	training's multi_logloss: 0.383716
# [457]	training's multi_logloss: 0.383635
# [458]	training's multi_logloss: 0.383566
# [459]	training's multi_logloss: 0.383488
# [460]	training's multi_logloss: 0.383313
# [461]	training's multi_logloss: 0.383199
# [462]	training's multi_logloss: 0.383112
# [463]	training's multi_logloss: 0.383035
# [464]	training's multi_logloss: 0.382926
# [465]	training's multi_logloss: 0.382851
# [466]	training's multi_logloss: 0.382686
# [467]	training's multi_logloss: 0.382537
# [468]	training's multi_logloss: 0.382462
# [469]	training's multi_logloss: 0.382385
# [470]	training's multi_logloss: 0.38229
# [471]	training's multi_logloss: 0.382166
# [472]	training's multi_logloss: 0.382081
# [473]	training's multi_logloss: 0.381997
# [474]	training's multi_logloss: 0.381908
# [475]	training's multi_logloss: 0.381789
# [476]	training's multi_logloss: 0.381696
# [477]	training's multi_logloss: 0.381572
# [478]	training's multi_logloss: 0.381496
# [479]	training's multi_logloss: 0.381326
# [480]	training's multi_logloss: 0.381235
# [481]	training's multi_logloss: 0.381146
# [482]	training's multi_logloss: 0.380957
# [483]	training's multi_logloss: 0.380881
# [484]	training's multi_logloss: 0.380791
# [485]	training's multi_logloss: 0.380703
# [486]	training's multi_logloss: 0.38044
# [487]	training's multi_logloss: 0.380322
# [488]	training's multi_logloss: 0.380185
# [489]	training's multi_logloss: 0.380089
# [490]	training's multi_logloss: 0.380011
# [491]	training's multi_logloss: 0.37993
# [492]	training's multi_logloss: 0.379862
# [493]	training's multi_logloss: 0.379776
# [494]	training's multi_logloss: 0.379687
# [495]	training's multi_logloss: 0.379571
# [496]	training's multi_logloss: 0.379469
# [497]	training's multi_logloss: 0.379363
# [498]	training's multi_logloss: 0.379275
# [499]	training's multi_logloss: 0.379197
# [500]	training's multi_logloss: 0.379124
# [501]	training's multi_logloss: 0.379062
# [502]	training's multi_logloss: 0.378982
# [503]	training's multi_logloss: 0.378797
# [504]	training's multi_logloss: 0.378712
# [505]	training's multi_logloss: 0.378577
# [506]	training's multi_logloss: 0.378424
# [507]	training's multi_logloss: 0.37833
# [508]	training's multi_logloss: 0.37817
# [509]	training's multi_logloss: 0.378017
# [510]	training's multi_logloss: 0.377937
# [511]	training's multi_logloss: 0.377842
# [512]	training's multi_logloss: 0.377762
# [513]	training's multi_logloss: 0.377685
# [514]	training's multi_logloss: 0.377594
# [515]	training's multi_logloss: 0.377506
# [516]	training's multi_logloss: 0.377433
# [517]	training's multi_logloss: 0.377363
# [518]	training's multi_logloss: 0.377283
# [519]	training's multi_logloss: 0.377198
# [520]	training's multi_logloss: 0.377118
# [521]	training's multi_logloss: 0.377027
# [522]	training's multi_logloss: 0.3769
# [523]	training's multi_logloss: 0.376817
# [524]	training's multi_logloss: 0.376728
# [525]	training's multi_logloss: 0.376648
# [526]	training's multi_logloss: 0.376569
# [527]	training's multi_logloss: 0.376446
# [528]	training's multi_logloss: 0.37635
# [529]	training's multi_logloss: 0.376263
# [530]	training's multi_logloss: 0.376175
# [531]	training's multi_logloss: 0.37609
# [532]	training's multi_logloss: 0.37602
# [533]	training's multi_logloss: 0.375953
# [534]	training's multi_logloss: 0.37589
# [535]	training's multi_logloss: 0.375786
# [536]	training's multi_logloss: 0.375686
# [537]	training's multi_logloss: 0.375614
# [538]	training's multi_logloss: 0.375545
# [539]	training's multi_logloss: 0.37546
# [540]	training's multi_logloss: 0.375389
# [541]	training's multi_logloss: 0.375321
# [542]	training's multi_logloss: 0.375186
# [543]	training's multi_logloss: 0.375125
# [544]	training's multi_logloss: 0.375049
# [545]	training's multi_logloss: 0.374964
# [546]	training's multi_logloss: 0.374875
# [547]	training's multi_logloss: 0.3748
# [548]	training's multi_logloss: 0.374708
# [549]	training's multi_logloss: 0.374635
# [550]	training's multi_logloss: 0.374565
# [551]	training's multi_logloss: 0.374478
# [552]	training's multi_logloss: 0.374407
# [553]	training's multi_logloss: 0.374344
# [554]	training's multi_logloss: 0.374212
# [555]	training's multi_logloss: 0.374128
# [556]	training's multi_logloss: 0.374048
# [557]	training's multi_logloss: 0.373977
# [558]	training's multi_logloss: 0.373901
# [559]	training's multi_logloss: 0.373826
# [560]	training's multi_logloss: 0.373762
# [561]	training's multi_logloss: 0.373664
# [562]	training's multi_logloss: 0.373575
# [563]	training's multi_logloss: 0.373472
# [564]	training's multi_logloss: 0.373394
# [565]	training's multi_logloss: 0.373311
# [566]	training's multi_logloss: 0.373233
# [567]	training's multi_logloss: 0.373058
# [568]	training's multi_logloss: 0.372956
# [569]	training's multi_logloss: 0.372864
# [570]	training's multi_logloss: 0.372771
# [571]	training's multi_logloss: 0.372697
# [572]	training's multi_logloss: 0.372629
# [573]	training's multi_logloss: 0.372526
# [574]	training's multi_logloss: 0.372451
# [575]	training's multi_logloss: 0.372322
# [576]	training's multi_logloss: 0.372253
# [577]	training's multi_logloss: 0.372173
# [578]	training's multi_logloss: 0.372114
# [579]	training's multi_logloss: 0.372047
# [580]	training's multi_logloss: 0.371962
# [581]	training's multi_logloss: 0.371853
# [582]	training's multi_logloss: 0.371747
# [583]	training's multi_logloss: 0.371675
# [584]	training's multi_logloss: 0.371586
# [585]	training's multi_logloss: 0.37151
# [586]	training's multi_logloss: 0.371444
# [587]	training's multi_logloss: 0.371373
# [588]	training's multi_logloss: 0.37131
# [589]	training's multi_logloss: 0.371248
# [590]	training's multi_logloss: 0.371179
# [591]	training's multi_logloss: 0.371065
# [592]	training's multi_logloss: 0.370977
# [593]	training's multi_logloss: 0.370913
# [594]	training's multi_logloss: 0.370802
# [595]	training's multi_logloss: 0.370744
# [596]	training's multi_logloss: 0.37064
# [597]	training's multi_logloss: 0.370573
# [598]	training's multi_logloss: 0.370421
# [599]	training's multi_logloss: 0.370365
# [600]	training's multi_logloss: 0.370289
# [601]	training's multi_logloss: 0.370202
# [602]	training's multi_logloss: 0.370084
# [603]	training's multi_logloss: 0.370016
# [604]	training's multi_logloss: 0.369908
# [605]	training's multi_logloss: 0.369811
# [606]	training's multi_logloss: 0.369744
# [607]	training's multi_logloss: 0.369669
# [608]	training's multi_logloss: 0.3696
# [609]	training's multi_logloss: 0.369516
# [610]	training's multi_logloss: 0.369445
# [611]	training's multi_logloss: 0.369376
# [612]	training's multi_logloss: 0.36926
# [613]	training's multi_logloss: 0.36918
# [614]	training's multi_logloss: 0.36912
# [615]	training's multi_logloss: 0.369044
# [616]	training's multi_logloss: 0.368973
# [617]	training's multi_logloss: 0.368853
# [618]	training's multi_logloss: 0.368798
# [619]	training's multi_logloss: 0.368732
# [620]	training's multi_logloss: 0.36866
# [621]	training's multi_logloss: 0.368583
# [622]	training's multi_logloss: 0.368506
# [623]	training's multi_logloss: 0.368383
# [624]	training's multi_logloss: 0.368319
# [625]	training's multi_logloss: 0.368234
# [626]	training's multi_logloss: 0.368065
# [627]	training's multi_logloss: 0.367939
# [628]	training's multi_logloss: 0.367842
# [629]	training's multi_logloss: 0.367752
# [630]	training's multi_logloss: 0.367647
# [631]	training's multi_logloss: 0.367564
# [632]	training's multi_logloss: 0.367497
# [633]	training's multi_logloss: 0.367401
# [634]	training's multi_logloss: 0.36731
# [635]	training's multi_logloss: 0.367219
# [636]	training's multi_logloss: 0.36716
# [637]	training's multi_logloss: 0.367094
# [638]	training's multi_logloss: 0.367005
# [639]	training's multi_logloss: 0.36694
# [640]	training's multi_logloss: 0.366805
# [641]	training's multi_logloss: 0.366729
# [642]	training's multi_logloss: 0.366651
# [643]	training's multi_logloss: 0.366577
# [644]	training's multi_logloss: 0.366507
# [645]	training's multi_logloss: 0.366436
# [646]	training's multi_logloss: 0.366373
# [647]	training's multi_logloss: 0.366284
# [648]	training's multi_logloss: 0.366217
# [649]	training's multi_logloss: 0.366137
# [650]	training's multi_logloss: 0.366069
# [651]	training's multi_logloss: 0.365962
# [652]	training's multi_logloss: 0.365877
# [653]	training's multi_logloss: 0.365797
# [654]	training's multi_logloss: 0.36572
# [655]	training's multi_logloss: 0.365656
# [656]	training's multi_logloss: 0.365588
# [657]	training's multi_logloss: 0.365524
# [658]	training's multi_logloss: 0.365448
# [659]	training's multi_logloss: 0.365377
# [660]	training's multi_logloss: 0.365294
# [661]	training's multi_logloss: 0.365205
# [662]	training's multi_logloss: 0.365149
# [663]	training's multi_logloss: 0.365055
# [664]	training's multi_logloss: 0.364989
# [665]	training's multi_logloss: 0.364918
# [666]	training's multi_logloss: 0.36481
# [667]	training's multi_logloss: 0.364705
# [668]	training's multi_logloss: 0.364629
# [669]	training's multi_logloss: 0.36456
# [670]	training's multi_logloss: 0.364459
# [671]	training's multi_logloss: 0.364393
# [672]	training's multi_logloss: 0.364295
# [673]	training's multi_logloss: 0.364222
# [674]	training's multi_logloss: 0.364164
# [675]	training's multi_logloss: 0.364107
# [676]	training's multi_logloss: 0.364024
# [677]	training's multi_logloss: 0.363944
# [678]	training's multi_logloss: 0.363867
# [679]	training's multi_logloss: 0.363803
# [680]	training's multi_logloss: 0.363688
# [681]	training's multi_logloss: 0.363564
# [682]	training's multi_logloss: 0.36349
# [683]	training's multi_logloss: 0.363407
# [684]	training's multi_logloss: 0.363338
# [685]	training's multi_logloss: 0.363231
# [686]	training's multi_logloss: 0.363166
# [687]	training's multi_logloss: 0.363096
# [688]	training's multi_logloss: 0.363034
# [689]	training's multi_logloss: 0.362971
# [690]	training's multi_logloss: 0.362906
# [691]	training's multi_logloss: 0.362848
# [692]	training's multi_logloss: 0.362781
# [693]	training's multi_logloss: 0.362721
# [694]	training's multi_logloss: 0.362606
# [695]	training's multi_logloss: 0.362546
# [696]	training's multi_logloss: 0.362477
# [697]	training's multi_logloss: 0.362349
# [698]	training's multi_logloss: 0.362283
# [699]	training's multi_logloss: 0.362229
# [700]	training's multi_logloss: 0.362153
# [701]	training's multi_logloss: 0.362064
# [702]	training's multi_logloss: 0.362004
# [703]	training's multi_logloss: 0.361934
# [704]	training's multi_logloss: 0.361875
# [705]	training's multi_logloss: 0.361808
# [706]	training's multi_logloss: 0.361748
# [707]	training's multi_logloss: 0.361619
# [708]	training's multi_logloss: 0.361564
# [709]	training's multi_logloss: 0.361474
# [710]	training's multi_logloss: 0.361375
# [711]	training's multi_logloss: 0.361239
# [712]	training's multi_logloss: 0.361127
# [713]	training's multi_logloss: 0.361049
# [714]	training's multi_logloss: 0.360971
# [715]	training's multi_logloss: 0.360903
# [716]	training's multi_logloss: 0.360841
# [717]	training's multi_logloss: 0.360765
# [718]	training's multi_logloss: 0.360682
# [719]	training's multi_logloss: 0.360613
# [720]	training's multi_logloss: 0.360545
# [721]	training's multi_logloss: 0.360491
# [722]	training's multi_logloss: 0.360416
# [723]	training's multi_logloss: 0.360293
# [724]	training's multi_logloss: 0.360222
# [725]	training's multi_logloss: 0.360003
# [726]	training's multi_logloss: 0.359917
# [727]	training's multi_logloss: 0.359831
# [728]	training's multi_logloss: 0.359766
# [729]	training's multi_logloss: 0.359707
# [730]	training's multi_logloss: 0.359637
# [731]	training's multi_logloss: 0.359565
# [732]	training's multi_logloss: 0.359502
# [733]	training's multi_logloss: 0.359421
# [734]	training's multi_logloss: 0.359355
# [735]	training's multi_logloss: 0.35924
# [736]	training's multi_logloss: 0.359176
# [737]	training's multi_logloss: 0.359103
# [738]	training's multi_logloss: 0.359027
# [739]	training's multi_logloss: 0.358942
# [740]	training's multi_logloss: 0.358858
# [741]	training's multi_logloss: 0.358776
# [742]	training's multi_logloss: 0.358708
# [743]	training's multi_logloss: 0.358646
# [744]	training's multi_logloss: 0.358555
# [745]	training's multi_logloss: 0.358449
# [746]	training's multi_logloss: 0.358378
# [747]	training's multi_logloss: 0.358317
# [748]	training's multi_logloss: 0.358255
# [749]	training's multi_logloss: 0.358188
# [750]	training's multi_logloss: 0.35811
# [751]	training's multi_logloss: 0.358035
# [752]	training's multi_logloss: 0.357959
# [753]	training's multi_logloss: 0.357896
# [754]	training's multi_logloss: 0.357838
# [755]	training's multi_logloss: 0.357654
# [756]	training's multi_logloss: 0.3576
# [757]	training's multi_logloss: 0.357527
# [758]	training's multi_logloss: 0.357442
# [759]	training's multi_logloss: 0.35734
# [760]	training's multi_logloss: 0.357262
# [761]	training's multi_logloss: 0.357202
# [762]	training's multi_logloss: 0.357123
# [763]	training's multi_logloss: 0.357045
# [764]	training's multi_logloss: 0.356978
# [765]	training's multi_logloss: 0.356899
# [766]	training's multi_logloss: 0.356825
# [767]	training's multi_logloss: 0.356751
# [768]	training's multi_logloss: 0.35669
# [769]	training's multi_logloss: 0.356546
# [770]	training's multi_logloss: 0.356363
# [771]	training's multi_logloss: 0.356301
# [772]	training's multi_logloss: 0.356228
# [773]	training's multi_logloss: 0.356147
# [774]	training's multi_logloss: 0.356072
# [775]	training's multi_logloss: 0.355944
# [776]	training's multi_logloss: 0.355869
# [777]	training's multi_logloss: 0.355786
# [778]	training's multi_logloss: 0.355715
# [779]	training's multi_logloss: 0.355645
# [780]	training's multi_logloss: 0.355569
# [781]	training's multi_logloss: 0.355495
# [782]	training's multi_logloss: 0.355434
# [783]	training's multi_logloss: 0.355366
# [784]	training's multi_logloss: 0.355297
# [785]	training's multi_logloss: 0.355225
# [786]	training's multi_logloss: 0.355153
# [787]	training's multi_logloss: 0.355068
# [788]	training's multi_logloss: 0.354997
# [789]	training's multi_logloss: 0.354904
# [790]	training's multi_logloss: 0.354843
# [791]	training's multi_logloss: 0.354766
# [792]	training's multi_logloss: 0.354701
# [793]	training's multi_logloss: 0.354623
# [794]	training's multi_logloss: 0.354556
# [795]	training's multi_logloss: 0.354502
# [796]	training's multi_logloss: 0.354416
# [797]	training's multi_logloss: 0.354333
# [798]	training's multi_logloss: 0.354256
# [799]	training's multi_logloss: 0.354207
# [800]	training's multi_logloss: 0.354112
# [801]	training's multi_logloss: 0.354039
# [802]	training's multi_logloss: 0.353973
# [803]	training's multi_logloss: 0.353827
# [804]	training's multi_logloss: 0.353748
# [805]	training's multi_logloss: 0.353678
# [806]	training's multi_logloss: 0.353608
# [807]	training's multi_logloss: 0.353546
# [808]	training's multi_logloss: 0.353404
# [809]	training's multi_logloss: 0.353343
# [810]	training's multi_logloss: 0.353231
# [811]	training's multi_logloss: 0.353117
# [812]	training's multi_logloss: 0.352982
# [813]	training's multi_logloss: 0.352913
# [814]	training's multi_logloss: 0.352831
# [815]	training's multi_logloss: 0.352763
# [816]	training's multi_logloss: 0.352687
# [817]	training's multi_logloss: 0.35257
# [818]	training's multi_logloss: 0.352443
# [819]	training's multi_logloss: 0.352368
# [820]	training's multi_logloss: 0.35229
# [821]	training's multi_logloss: 0.352231
# [822]	training's multi_logloss: 0.352135
# [823]	training's multi_logloss: 0.352052
# [824]	training's multi_logloss: 0.351951
# [825]	training's multi_logloss: 0.351864
# [826]	training's multi_logloss: 0.351807
# [827]	training's multi_logloss: 0.351739
# [828]	training's multi_logloss: 0.351672
# [829]	training's multi_logloss: 0.35161
# [830]	training's multi_logloss: 0.351545
# [831]	training's multi_logloss: 0.351472
# [832]	training's multi_logloss: 0.351397
# [833]	training's multi_logloss: 0.351324
# [834]	training's multi_logloss: 0.351256
# [835]	training's multi_logloss: 0.351194
# [836]	training's multi_logloss: 0.351084
# [837]	training's multi_logloss: 0.351025
# [838]	training's multi_logloss: 0.350972
# [839]	training's multi_logloss: 0.350909
# [840]	training's multi_logloss: 0.350846
# [841]	training's multi_logloss: 0.350776
# [842]	training's multi_logloss: 0.350715
# [843]	training's multi_logloss: 0.350654
# [844]	training's multi_logloss: 0.350554
# [845]	training's multi_logloss: 0.350501
# [846]	training's multi_logloss: 0.350422
# [847]	training's multi_logloss: 0.350367
# [848]	training's multi_logloss: 0.35031
# [849]	training's multi_logloss: 0.350247
# [850]	training's multi_logloss: 0.350192
# [851]	training's multi_logloss: 0.350126
# [852]	training's multi_logloss: 0.350067
# [853]	training's multi_logloss: 0.350001
# [854]	training's multi_logloss: 0.349903
# [855]	training's multi_logloss: 0.349835
# [856]	training's multi_logloss: 0.349779
# [857]	training's multi_logloss: 0.349672
# [858]	training's multi_logloss: 0.349617
# [859]	training's multi_logloss: 0.349565
# [860]	training's multi_logloss: 0.349518
# [861]	training's multi_logloss: 0.349442
# [862]	training's multi_logloss: 0.349386
# [863]	training's multi_logloss: 0.349321
# [864]	training's multi_logloss: 0.349275
# [865]	training's multi_logloss: 0.349219
# [866]	training's multi_logloss: 0.349116
# [867]	training's multi_logloss: 0.349049
# [868]	training's multi_logloss: 0.348988
# [869]	training's multi_logloss: 0.348932
# [870]	training's multi_logloss: 0.348877
# [871]	training's multi_logloss: 0.348826
# [872]	training's multi_logloss: 0.348754
# [873]	training's multi_logloss: 0.348694
# [874]	training's multi_logloss: 0.34864
# [875]	training's multi_logloss: 0.348574
# [876]	training's multi_logloss: 0.348499
# [877]	training's multi_logloss: 0.348435
# [878]	training's multi_logloss: 0.34832
# [879]	training's multi_logloss: 0.348265
# [880]	training's multi_logloss: 0.348213
# [881]	training's multi_logloss: 0.348105
# [882]	training's multi_logloss: 0.348055
# [883]	training's multi_logloss: 0.347977
# [884]	training's multi_logloss: 0.347883
# [885]	training's multi_logloss: 0.347776
# [886]	training's multi_logloss: 0.347719
# [887]	training's multi_logloss: 0.347649
# [888]	training's multi_logloss: 0.347569
# [889]	training's multi_logloss: 0.347494
# [890]	training's multi_logloss: 0.347426
# [891]	training's multi_logloss: 0.34736
# [892]	training's multi_logloss: 0.347291
# [893]	training's multi_logloss: 0.347232
# [894]	training's multi_logloss: 0.347176
# [895]	training's multi_logloss: 0.347082
# [896]	training's multi_logloss: 0.347026
# [897]	training's multi_logloss: 0.346956
# [898]	training's multi_logloss: 0.346872
# [899]	training's multi_logloss: 0.346814
# [900]	training's multi_logloss: 0.346758
# [901]	training's multi_logloss: 0.346706
# [902]	training's multi_logloss: 0.346651
# [903]	training's multi_logloss: 0.346575
# [904]	training's multi_logloss: 0.346511
# [905]	training's multi_logloss: 0.346429
# [906]	training's multi_logloss: 0.346378
# [907]	training's multi_logloss: 0.346328
# [908]	training's multi_logloss: 0.346242
# [909]	training's multi_logloss: 0.346156
# [910]	training's multi_logloss: 0.346085
# [911]	training's multi_logloss: 0.346026
# [912]	training's multi_logloss: 0.345971
# [913]	training's multi_logloss: 0.345895
# [914]	training's multi_logloss: 0.345842
# [915]	training's multi_logloss: 0.345759
# [916]	training's multi_logloss: 0.345706
# [917]	training's multi_logloss: 0.345656
# [918]	training's multi_logloss: 0.34558
# [919]	training's multi_logloss: 0.345525
# [920]	training's multi_logloss: 0.345453
# [921]	training's multi_logloss: 0.345401
# [922]	training's multi_logloss: 0.345343
# [923]	training's multi_logloss: 0.345278
# [924]	training's multi_logloss: 0.345218
# [925]	training's multi_logloss: 0.345165
# [926]	training's multi_logloss: 0.345109
# [927]	training's multi_logloss: 0.345057
# [928]	training's multi_logloss: 0.345009
# [929]	training's multi_logloss: 0.344957
# [930]	training's multi_logloss: 0.344898
# [931]	training's multi_logloss: 0.344823
# [932]	training's multi_logloss: 0.344694
# [933]	training's multi_logloss: 0.344637
# [934]	training's multi_logloss: 0.344577
# [935]	training's multi_logloss: 0.344523
# [936]	training's multi_logloss: 0.344449
# [937]	training's multi_logloss: 0.344366
# [938]	training's multi_logloss: 0.344307
# [939]	training's multi_logloss: 0.344174
# [940]	training's multi_logloss: 0.344105
# [941]	training's multi_logloss: 0.344049
# [942]	training's multi_logloss: 0.343976
# [943]	training's multi_logloss: 0.343921
# [944]	training's multi_logloss: 0.343832
# [945]	training's multi_logloss: 0.343774
# [946]	training's multi_logloss: 0.343718
# [947]	training's multi_logloss: 0.343656
# [948]	training's multi_logloss: 0.34359
# [949]	training's multi_logloss: 0.34353
# [950]	training's multi_logloss: 0.343477
# [951]	training's multi_logloss: 0.343369
# [952]	training's multi_logloss: 0.343317
# [953]	training's multi_logloss: 0.343242
# [954]	training's multi_logloss: 0.343182
# [955]	training's multi_logloss: 0.34312
# [956]	training's multi_logloss: 0.343036
# [957]	training's multi_logloss: 0.342932
# [958]	training's multi_logloss: 0.342856
# [959]	training's multi_logloss: 0.342796
# [960]	training's multi_logloss: 0.342737
# [961]	training's multi_logloss: 0.342682
# [962]	training's multi_logloss: 0.342533
# [963]	training's multi_logloss: 0.342469
# [964]	training's multi_logloss: 0.342414
# [965]	training's multi_logloss: 0.342355
# [966]	training's multi_logloss: 0.342303
# [967]	training's multi_logloss: 0.342239
# [968]	training's multi_logloss: 0.342182
# [969]	training's multi_logloss: 0.342128
# [970]	training's multi_logloss: 0.34203
# [971]	training's multi_logloss: 0.341973
# [972]	training's multi_logloss: 0.341927
# [973]	training's multi_logloss: 0.34188
# [974]	training's multi_logloss: 0.341817
# [975]	training's multi_logloss: 0.341764
# [976]	training's multi_logloss: 0.341701
# [977]	training's multi_logloss: 0.341652
# [978]	training's multi_logloss: 0.341585
# [979]	training's multi_logloss: 0.341533
# [980]	training's multi_logloss: 0.341488
# [981]	training's multi_logloss: 0.341439
# [982]	training's multi_logloss: 0.34138
# [983]	training's multi_logloss: 0.341331
# [984]	training's multi_logloss: 0.341275
# [985]	training's multi_logloss: 0.341227
# [986]	training's multi_logloss: 0.341137
# [987]	training's multi_logloss: 0.341086
# [988]	training's multi_logloss: 0.341028
# [989]	training's multi_logloss: 0.340916
# [990]	training's multi_logloss: 0.340862
# [991]	training's multi_logloss: 0.340801
# [992]	training's multi_logloss: 0.340683
# [993]	training's multi_logloss: 0.340628
# [994]	training's multi_logloss: 0.340561
# [995]	training's multi_logloss: 0.340509
# [996]	training's multi_logloss: 0.340454
# [997]	training's multi_logloss: 0.340397
# [998]	training's multi_logloss: 0.340325
# [999]	training's multi_logloss: 0.340281
# [1000]	training's multi_logloss: 0.340217
# [1001]	training's multi_logloss: 0.340142
# [1002]	training's multi_logloss: 0.340094
# [1003]	training's multi_logloss: 0.340036
# [1004]	training's multi_logloss: 0.339982
# [1005]	training's multi_logloss: 0.339903
# [1006]	training's multi_logloss: 0.339832
# [1007]	training's multi_logloss: 0.339737
# [1008]	training's multi_logloss: 0.339684
# [1009]	training's multi_logloss: 0.339629
# [1010]	training's multi_logloss: 0.33956
# [1011]	training's multi_logloss: 0.339496
# [1012]	training's multi_logloss: 0.339441
# [1013]	training's multi_logloss: 0.339304
# [1014]	training's multi_logloss: 0.339246
# [1015]	training's multi_logloss: 0.339164
# [1016]	training's multi_logloss: 0.33909
# [1017]	training's multi_logloss: 0.339024
# [1018]	training's multi_logloss: 0.338955
# [1019]	training's multi_logloss: 0.338897
# [1020]	training's multi_logloss: 0.338737
# [1021]	training's multi_logloss: 0.338672
# [1022]	training's multi_logloss: 0.338619
# [1023]	training's multi_logloss: 0.338548
# [1024]	training's multi_logloss: 0.338476
# [1025]	training's multi_logloss: 0.338426
# [1026]	training's multi_logloss: 0.338352
# [1027]	training's multi_logloss: 0.338293
# [1028]	training's multi_logloss: 0.338229
# [1029]	training's multi_logloss: 0.338152
# [1030]	training's multi_logloss: 0.338085
# [1031]	training's multi_logloss: 0.337977
# [1032]	training's multi_logloss: 0.337905
# [1033]	training's multi_logloss: 0.337852
# [1034]	training's multi_logloss: 0.3378
# [1035]	training's multi_logloss: 0.337748
# [1036]	training's multi_logloss: 0.337498
# [1037]	training's multi_logloss: 0.337425
# [1038]	training's multi_logloss: 0.337369
# [1039]	training's multi_logloss: 0.33727
# [1040]	training's multi_logloss: 0.337205
# [1041]	training's multi_logloss: 0.337144
# [1042]	training's multi_logloss: 0.337089
# [1043]	training's multi_logloss: 0.337035
# [1044]	training's multi_logloss: 0.336974
# [1045]	training's multi_logloss: 0.33692
# [1046]	training's multi_logloss: 0.33687
# [1047]	training's multi_logloss: 0.336776
# [1048]	training's multi_logloss: 0.336713
# [1049]	training's multi_logloss: 0.336658
# [1050]	training's multi_logloss: 0.336601
# [1051]	training's multi_logloss: 0.336544
# [1052]	training's multi_logloss: 0.336479
# [1053]	training's multi_logloss: 0.336421
# [1054]	training's multi_logloss: 0.336304
# [1055]	training's multi_logloss: 0.336243
# [1056]	training's multi_logloss: 0.336194
# [1057]	training's multi_logloss: 0.33614
# [1058]	training's multi_logloss: 0.336096
# [1059]	training's multi_logloss: 0.336039
# [1060]	training's multi_logloss: 0.335981
# [1061]	training's multi_logloss: 0.335923
# [1062]	training's multi_logloss: 0.335795
# [1063]	training's multi_logloss: 0.335721
# [1064]	training's multi_logloss: 0.335664
# [1065]	training's multi_logloss: 0.335471
# [1066]	training's multi_logloss: 0.335407
# [1067]	training's multi_logloss: 0.335345
# [1068]	training's multi_logloss: 0.335294
# [1069]	training's multi_logloss: 0.335227
# [1070]	training's multi_logloss: 0.335174
# [1071]	training's multi_logloss: 0.334991
# [1072]	training's multi_logloss: 0.334929
# [1073]	training's multi_logloss: 0.334878
# [1074]	training's multi_logloss: 0.33481
# [1075]	training's multi_logloss: 0.334745
# [1076]	training's multi_logloss: 0.334673
# [1077]	training's multi_logloss: 0.334608
# [1078]	training's multi_logloss: 0.334477
# [1079]	training's multi_logloss: 0.334426
# [1080]	training's multi_logloss: 0.334303
# [1081]	training's multi_logloss: 0.334246
# [1082]	training's multi_logloss: 0.334193
# [1083]	training's multi_logloss: 0.33411
# [1084]	training's multi_logloss: 0.334028
# [1085]	training's multi_logloss: 0.333981
# [1086]	training's multi_logloss: 0.333923
# [1087]	training's multi_logloss: 0.333843
# [1088]	training's multi_logloss: 0.333783
# [1089]	training's multi_logloss: 0.333716
# [1090]	training's multi_logloss: 0.333669
# [1091]	training's multi_logloss: 0.333558
# [1092]	training's multi_logloss: 0.333498
# [1093]	training's multi_logloss: 0.333431
# [1094]	training's multi_logloss: 0.333365
# [1095]	training's multi_logloss: 0.333294
# [1096]	training's multi_logloss: 0.333237
# [1097]	training's multi_logloss: 0.333183
# [1098]	training's multi_logloss: 0.333136
# [1099]	training's multi_logloss: 0.333067
# [1100]	training's multi_logloss: 0.332987
# [1101]	training's multi_logloss: 0.332927
# [1102]	training's multi_logloss: 0.332835
# [1103]	training's multi_logloss: 0.332769
# [1104]	training's multi_logloss: 0.332718
# [1105]	training's multi_logloss: 0.332663
# [1106]	training's multi_logloss: 0.332597
# [1107]	training's multi_logloss: 0.332551
# [1108]	training's multi_logloss: 0.332415
# [1109]	training's multi_logloss: 0.332358
# [1110]	training's multi_logloss: 0.332279
# [1111]	training's multi_logloss: 0.332205
# [1112]	training's multi_logloss: 0.332143
# [1113]	training's multi_logloss: 0.332092
# [1114]	training's multi_logloss: 0.332035
# [1115]	training's multi_logloss: 0.331924
# [1116]	training's multi_logloss: 0.331863
# [1117]	training's multi_logloss: 0.331793
# [1118]	training's multi_logloss: 0.331736
# [1119]	training's multi_logloss: 0.331686
# [1120]	training's multi_logloss: 0.331611
# [1121]	training's multi_logloss: 0.331543
# [1122]	training's multi_logloss: 0.33145
# [1123]	training's multi_logloss: 0.33139
# [1124]	training's multi_logloss: 0.331323
# [1125]	training's multi_logloss: 0.331252
# [1126]	training's multi_logloss: 0.331187
# [1127]	training's multi_logloss: 0.331122
# [1128]	training's multi_logloss: 0.33105
# [1129]	training's multi_logloss: 0.330986
# [1130]	training's multi_logloss: 0.330932
# [1131]	training's multi_logloss: 0.330863
# [1132]	training's multi_logloss: 0.330815
# [1133]	training's multi_logloss: 0.330715
# [1134]	training's multi_logloss: 0.330653
# [1135]	training's multi_logloss: 0.330595
# [1136]	training's multi_logloss: 0.330547
# [1137]	training's multi_logloss: 0.330467
# [1138]	training's multi_logloss: 0.33042
# [1139]	training's multi_logloss: 0.330343
# [1140]	training's multi_logloss: 0.33029
# [1141]	training's multi_logloss: 0.330239
# [1142]	training's multi_logloss: 0.33017
# [1143]	training's multi_logloss: 0.330116
# [1144]	training's multi_logloss: 0.330065
# [1145]	training's multi_logloss: 0.329993
# [1146]	training's multi_logloss: 0.329932
# [1147]	training's multi_logloss: 0.329885
# [1148]	training's multi_logloss: 0.329843
# [1149]	training's multi_logloss: 0.329774
# [1150]	training's multi_logloss: 0.329729
# [1151]	training's multi_logloss: 0.329665
# [1152]	training's multi_logloss: 0.329622
# [1153]	training's multi_logloss: 0.329506
# [1154]	training's multi_logloss: 0.329451
# [1155]	training's multi_logloss: 0.329337
# [1156]	training's multi_logloss: 0.329281
# [1157]	training's multi_logloss: 0.329212
# [1158]	training's multi_logloss: 0.329147
# [1159]	training's multi_logloss: 0.329087
# [1160]	training's multi_logloss: 0.329031
# [1161]	training's multi_logloss: 0.328976
# [1162]	training's multi_logloss: 0.328916
# [1163]	training's multi_logloss: 0.328867
# [1164]	training's multi_logloss: 0.328811
# [1165]	training's multi_logloss: 0.328755
# [1166]	training's multi_logloss: 0.328647
# [1167]	training's multi_logloss: 0.328587
# ...
# [1221]	training's multi_logloss: 0.325256
# [1222]	training's multi_logloss: 0.325212
# [1223]	training's multi_logloss: 0.325164
# [1224]	training's multi_logloss: 0.325103
# [1225]	training's multi_logloss: 0.325042
# [1226]	training's multi_logloss: 0.324983
# [1227]	training's multi_logloss: 0.3249
# [1228]	training's multi_logloss: 0.324848
# [1229]	training's multi_logloss: 0.324794
# [1230]	training's multi_logloss: 0.324738
# [1231]	training's multi_logloss: 0.324679
# [1232]	training's multi_logloss: 0.324624
# [1233]	training's multi_logloss: 0.32457
# [1234]	training's multi_logloss: 0.324513
# [1235]	training's multi_logloss: 0.324437
# [1236]	training's multi_logloss: 0.324378
# [1237]	training's multi_logloss: 0.324327
# [1238]	training's multi_logloss: 0.324284
# [1239]	training's multi_logloss: 0.324232
# [1240]	training's multi_logloss: 0.324186
# [1241]	training's multi_logloss: 0.324142
# [1242]	training's multi_logloss: 0.324071
# [1243]	training's multi_logloss: 0.324018
# [1244]	training's multi_logloss: 0.323941
# [1245]	training's multi_logloss: 0.323894
# [1246]	training's multi_logloss: 0.323853
# [1247]	training's multi_logloss: 0.323801
# [1248]	training's multi_logloss: 0.323743
# [1249]	training's multi_logloss: 0.32368
# [1250]	training's multi_logloss: 0.323631
# [1251]	training's multi_logloss: 0.323581
# [1252]	training's multi_logloss: 0.32353
# [1253]	training's multi_logloss: 0.323483
# [1254]	training's multi_logloss: 0.323433
# [1255]	training's multi_logloss: 0.323388
# [1256]	training's multi_logloss: 0.32331
# [1257]	training's multi_logloss: 0.323262
# [1258]	training's multi_logloss: 0.32321
# [1259]	training's multi_logloss: 0.323164
# [1260]	training's multi_logloss: 0.323118
# [1261]	training's multi_logloss: 0.32305
# [1262]	training's multi_logloss: 0.322989
# [1263]	training's multi_logloss: 0.322939
# [1264]	training's multi_logloss: 0.322875
# [1265]	training's multi_logloss: 0.322815
# [1266]	training's multi_logloss: 0.32274
# [1267]	training's multi_logloss: 0.322689
# [1268]	training's multi_logloss: 0.322637
# [1269]	training's multi_logloss: 0.322587
# [1270]	training's multi_logloss: 0.322527
# [1271]	training's multi_logloss: 0.322481
# [1272]	training's multi_logloss: 0.32243
# [1273]	training's multi_logloss: 0.322347
# [1274]	training's multi_logloss: 0.322305
# [1275]	training's multi_logloss: 0.322265
# [1276]	training's multi_logloss: 0.322166
# [1277]	training's multi_logloss: 0.322117
# [1278]	training's multi_logloss: 0.32207
# [1279]	training's multi_logloss: 0.322023
# [1280]	training's multi_logloss: 0.321977
# [1281]	training's multi_logloss: 0.321925
# [1282]	training's multi_logloss: 0.321876
# [1283]	training's multi_logloss: 0.321827
# [1284]	training's multi_logloss: 0.321755
# [1285]	training's multi_logloss: 0.321706
# [1286]	training's multi_logloss: 0.321657
# [1287]	training's multi_logloss: 0.321593
# [1288]	training's multi_logloss: 0.321535
# [1289]	training's multi_logloss: 0.321464
# [1290]	training's multi_logloss: 0.321413
# [1291]	training's multi_logloss: 0.321355
# [1292]	training's multi_logloss: 0.321307
# [1293]	training's multi_logloss: 0.321242
# [1294]	training's multi_logloss: 0.321201
# [1295]	training's multi_logloss: 0.321159
# [1296]	training's multi_logloss: 0.321112
# [1297]	training's multi_logloss: 0.321063
# [1298]	training's multi_logloss: 0.321008
# [1299]	training's multi_logloss: 0.320967
# [1300]	training's multi_logloss: 0.320902
# [1301]	training's multi_logloss: 0.32085
# [1302]	training's multi_logloss: 0.320803
# [1303]	training's multi_logloss: 0.320754
# [1304]	training's multi_logloss: 0.3207
# [1305]	training's multi_logloss: 0.320651
# [1306]	training's multi_logloss: 0.320597
# [1307]	training's multi_logloss: 0.320546
# [1308]	training's multi_logloss: 0.320497
# [1309]	training's multi_logloss: 0.320442
# [1310]	training's multi_logloss: 0.320369
# [1311]	training's multi_logloss: 0.320311
# [1312]	training's multi_logloss: 0.32026
# [1313]	training's multi_logloss: 0.320212
# [1314]	training's multi_logloss: 0.320153
# [1315]	training's multi_logloss: 0.320102
# [1316]	training's multi_logloss: 0.320028
# [1317]	training's multi_logloss: 0.31997
# [1318]	training's multi_logloss: 0.319909
# [1319]	training's multi_logloss: 0.319851
# [1320]	training's multi_logloss: 0.319792
# [1321]	training's multi_logloss: 0.319724
# [1322]	training's multi_logloss: 0.319667
# [1323]	training's multi_logloss: 0.319608
# [1324]	training's multi_logloss: 0.319557
# [1325]	training's multi_logloss: 0.319504
# [1326]	training's multi_logloss: 0.319452
# [1327]	training's multi_logloss: 0.319386
# [1328]	training's multi_logloss: 0.319341
# [1329]	training's multi_logloss: 0.319255
# [1330]	training's multi_logloss: 0.319205
# [1331]	training's multi_logloss: 0.319158
# [1332]	training's multi_logloss: 0.319078
# [1333]	training's multi_logloss: 0.318871
# [1334]	training's multi_logloss: 0.3188
# [1335]	training's multi_logloss: 0.318715
# [1336]	training's multi_logloss: 0.318652
# [1337]	training's multi_logloss: 0.318603
# [1338]	training's multi_logloss: 0.318564
# [1339]	training's multi_logloss: 0.318514
# [1340]	training's multi_logloss: 0.318463
# [1341]	training's multi_logloss: 0.318411
# [1342]	training's multi_logloss: 0.318364
# [1343]	training's multi_logloss: 0.318283
# [1344]	training's multi_logloss: 0.318233
# [1345]	training's multi_logloss: 0.318186
# [1346]	training's multi_logloss: 0.318134
# [1347]	training's multi_logloss: 0.318079
# [1348]	training's multi_logloss: 0.318005
# [1349]	training's multi_logloss: 0.317956
# [1350]	training's multi_logloss: 0.317902
# [1351]	training's multi_logloss: 0.317856
# [1352]	training's multi_logloss: 0.317803
# [1353]	training's multi_logloss: 0.317761
# [1354]	training's multi_logloss: 0.317715
# [1355]	training's multi_logloss: 0.317668
# [1356]	training's multi_logloss: 0.317604
# [1357]	training's multi_logloss: 0.317557
# [1358]	training's multi_logloss: 0.31748
# [1359]	training's multi_logloss: 0.317402
# [1360]	training's multi_logloss: 0.317343
# [1361]	training's multi_logloss: 0.317252
# [1362]	training's multi_logloss: 0.317151
# [1363]	training's multi_logloss: 0.317093
# [1364]	training's multi_logloss: 0.317047
# [1365]	training's multi_logloss: 0.316978
# [1366]	training's multi_logloss: 0.316932
# [1367]	training's multi_logloss: 0.316881
# [1368]	training's multi_logloss: 0.316834
# [1369]	training's multi_logloss: 0.316785
# [1370]	training's multi_logloss: 0.316738
# [1371]	training's multi_logloss: 0.316675
# [1372]	training's multi_logloss: 0.316634
# [1373]	training's multi_logloss: 0.316578
# [1374]	training's multi_logloss: 0.316526
# [1375]	training's multi_logloss: 0.31645
# [1376]	training's multi_logloss: 0.316399
# [1377]	training's multi_logloss: 0.316328
# [1378]	training's multi_logloss: 0.316261
# [1379]	training's multi_logloss: 0.31621
# [1380]	training's multi_logloss: 0.316155
# [1381]	training's multi_logloss: 0.316102
# [1382]	training's multi_logloss: 0.316057
# [1383]	training's multi_logloss: 0.315982
# [1384]	training's multi_logloss: 0.315932
# [1385]	training's multi_logloss: 0.315883
# [1386]	training's multi_logloss: 0.315787
# [1387]	training's multi_logloss: 0.315742
# [1388]	training's multi_logloss: 0.315691
# [1389]	training's multi_logloss: 0.31564
# [1390]	training's multi_logloss: 0.31559
# [1391]	training's multi_logloss: 0.315547
# [1392]	training's multi_logloss: 0.315493
# [1393]	training's multi_logloss: 0.315444
# [1394]	training's multi_logloss: 0.315382
# [1395]	training's multi_logloss: 0.315307
# [1396]	training's multi_logloss: 0.315252
# [1397]	training's multi_logloss: 0.315195
# [1398]	training's multi_logloss: 0.315119
# [1399]	training's multi_logloss: 0.315064
# [1400]	training's multi_logloss: 0.315004
# [1401]	training's multi_logloss: 0.314941
# [1402]	training's multi_logloss: 0.314879
# [1403]	training's multi_logloss: 0.314832
# [1404]	training's multi_logloss: 0.314783
# [1405]	training's multi_logloss: 0.314735
# [1406]	training's multi_logloss: 0.314684
# [1407]	training's multi_logloss: 0.314639
# [1408]	training's multi_logloss: 0.314592
# [1409]	training's multi_logloss: 0.314535
# [1410]	training's multi_logloss: 0.314475
# [1411]	training's multi_logloss: 0.314409
# [1412]	training's multi_logloss: 0.314344
# [1413]	training's multi_logloss: 0.31429
# [1414]	training's multi_logloss: 0.314232
# [1415]	training's multi_logloss: 0.31416
# [1416]	training's multi_logloss: 0.314095
# [1417]	training's multi_logloss: 0.314042
# [1418]	training's multi_logloss: 0.31397
# [1419]	training's multi_logloss: 0.313923
# [1420]	training's multi_logloss: 0.313844
# [1421]	training's multi_logloss: 0.313785
# [1422]	training's multi_logloss: 0.313721
# [1423]	training's multi_logloss: 0.313679
# [1424]	training's multi_logloss: 0.313555
# [1425]	training's multi_logloss: 0.313492
# [1426]	training's multi_logloss: 0.313433
# [1427]	training's multi_logloss: 0.313377
# [1428]	training's multi_logloss: 0.313327
# [1429]	training's multi_logloss: 0.313264
# [1430]	training's multi_logloss: 0.31322
# [1431]	training's multi_logloss: 0.313176
# [1432]	training's multi_logloss: 0.31313
# [1433]	training's multi_logloss: 0.313082
# [1434]	training's multi_logloss: 0.313009
# [1435]	training's multi_logloss: 0.312954
# [1436]	training's multi_logloss: 0.312908
# [1437]	training's multi_logloss: 0.312868
# [1438]	training's multi_logloss: 0.312787
# [1439]	training's multi_logloss: 0.312725
# [1440]	training's multi_logloss: 0.312676
# [1441]	training's multi_logloss: 0.312624
# [1442]	training's multi_logloss: 0.312577
# [1443]	training's multi_logloss: 0.312539
# [1444]	training's multi_logloss: 0.312492
# [1445]	training's multi_logloss: 0.312442
# [1446]	training's multi_logloss: 0.312373
# [1447]	training's multi_logloss: 0.312312
# [1448]	training's multi_logloss: 0.312268
# [1449]	training's multi_logloss: 0.312225
# [1450]	training's multi_logloss: 0.312183
# [1451]	training's multi_logloss: 0.312142
# [1452]	training's multi_logloss: 0.312081
# [1453]	training's multi_logloss: 0.312008
# [1454]	training's multi_logloss: 0.311951
# [1455]	training's multi_logloss: 0.311907
# [1456]	training's multi_logloss: 0.311854
# [1457]	training's multi_logloss: 0.311799
# [1458]	training's multi_logloss: 0.311752
# [1459]	training's multi_logloss: 0.311711
# [1460]	training's multi_logloss: 0.311664
# [1461]	training's multi_logloss: 0.311593
# [1462]	training's multi_logloss: 0.31154
# [1463]	training's multi_logloss: 0.311484
# [1464]	training's multi_logloss: 0.311431
# [1465]	training's multi_logloss: 0.311384
# [1466]	training's multi_logloss: 0.311331
# [1467]	training's multi_logloss: 0.311268
# [1468]	training's multi_logloss: 0.311224
# [1469]	training's multi_logloss: 0.311164
# [1470]	training's multi_logloss: 0.311111
# [1471]	training's multi_logloss: 0.311057
# [1472]	training's multi_logloss: 0.310961
# [1473]	training's multi_logloss: 0.310912
# [1474]	training's multi_logloss: 0.310857
# [1475]	training's multi_logloss: 0.310805
# [1476]	training's multi_logloss: 0.310769
# [1477]	training's multi_logloss: 0.310692
# [1478]	training's multi_logloss: 0.310637
# [1479]	training's multi_logloss: 0.310599
# [1480]	training's multi_logloss: 0.310559
# [1481]	training's multi_logloss: 0.310497
# [1482]	training's multi_logloss: 0.310421
# [1483]	training's multi_logloss: 0.310358
# [1484]	training's multi_logloss: 0.310275
# [1485]	training's multi_logloss: 0.310202
# [1486]	training's multi_logloss: 0.310145
# [1487]	training's multi_logloss: 0.3101
# [1488]	training's multi_logloss: 0.310038
# [1489]	training's multi_logloss: 0.309993
# [1490]	training's multi_logloss: 0.309957
# [1491]	training's multi_logloss: 0.309888
# [1492]	training's multi_logloss: 0.309825
# [1493]	training's multi_logloss: 0.309776
# [1494]	training's multi_logloss: 0.309731
# [1495]	training's multi_logloss: 0.309671
# [1496]	training's multi_logloss: 0.309623
# [1497]	training's multi_logloss: 0.309563
# [1498]	training's multi_logloss: 0.309515
# [1499]	training's multi_logloss: 0.309447
# [1500]	training's multi_logloss: 0.309401
# [1501]	training's multi_logloss: 0.309337
# [1502]	training's multi_logloss: 0.309297
# [1503]	training's multi_logloss: 0.309249
# [1504]	training's multi_logloss: 0.309181
# [1505]	training's multi_logloss: 0.309118
# [1506]	training's multi_logloss: 0.309069
# [1507]	training's multi_logloss: 0.309025
# [1508]	training's multi_logloss: 0.308927
# [1509]	training's multi_logloss: 0.308833
# [1510]	training's multi_logloss: 0.308789
# [1511]	training's multi_logloss: 0.308729
# [1512]	training's multi_logloss: 0.308672
# [1513]	training's multi_logloss: 0.308631
# [1514]	training's multi_logloss: 0.308576
# [1515]	training's multi_logloss: 0.308531
# [1516]	training's multi_logloss: 0.30849
# [1517]	training's multi_logloss: 0.308416
# [1518]	training's multi_logloss: 0.308371
# [1519]	training's multi_logloss: 0.308322
# [1520]	training's multi_logloss: 0.308282
# [1521]	training's multi_logloss: 0.308235
# [1522]	training's multi_logloss: 0.30819
# [1523]	training's multi_logloss: 0.308142
# [1524]	training's multi_logloss: 0.307956
# [1525]	training's multi_logloss: 0.307892
# [1526]	training's multi_logloss: 0.30784
# [1527]	training's multi_logloss: 0.307787
# [1528]	training's multi_logloss: 0.307735
# [1529]	training's multi_logloss: 0.307643
# [1530]	training's multi_logloss: 0.307584
# [1531]	training's multi_logloss: 0.307535
# [1532]	training's multi_logloss: 0.307484
# [1533]	training's multi_logloss: 0.30743
# [1534]	training's multi_logloss: 0.307388
# [1535]	training's multi_logloss: 0.30735
# [1536]	training's multi_logloss: 0.307286
# [1537]	training's multi_logloss: 0.307164
# [1538]	training's multi_logloss: 0.307117
# [1539]	training's multi_logloss: 0.307022
# [1540]	training's multi_logloss: 0.306937
# [1541]	training's multi_logloss: 0.306843
# [1542]	training's multi_logloss: 0.306708
# [1543]	training's multi_logloss: 0.306636
# [1544]	training's multi_logloss: 0.306588
# [1545]	training's multi_logloss: 0.306528
# [1546]	training's multi_logloss: 0.306487
# [1547]	training's multi_logloss: 0.306436
# [1548]	training's multi_logloss: 0.306372
# [1549]	training's multi_logloss: 0.306314
# [1550]	training's multi_logloss: 0.306265
# [1551]	training's multi_logloss: 0.306212
# [1552]	training's multi_logloss: 0.306172
# [1553]	training's multi_logloss: 0.306104
# [1554]	training's multi_logloss: 0.306063
# [1555]	training's multi_logloss: 0.306002
# [1556]	training's multi_logloss: 0.305947
# [1557]	training's multi_logloss: 0.305893
# [1558]	training's multi_logloss: 0.305844
# [1559]	training's multi_logloss: 0.305801
# [1560]	training's multi_logloss: 0.305684
# [1561]	training's multi_logloss: 0.305625
# [1562]	training's multi_logloss: 0.305572
# [1563]	training's multi_logloss: 0.305525
# [1564]	training's multi_logloss: 0.305456
# [1565]	training's multi_logloss: 0.3054
# [1566]	training's multi_logloss: 0.305355
# [1567]	training's multi_logloss: 0.305297
# [1568]	training's multi_logloss: 0.305248
# [1569]	training's multi_logloss: 0.305195
# [1570]	training's multi_logloss: 0.305119
# [1571]	training's multi_logloss: 0.305047
# [1572]	training's multi_logloss: 0.305003
# [1573]	training's multi_logloss: 0.30495
# [1574]	training's multi_logloss: 0.30489
# [1575]	training's multi_logloss: 0.304832
# [1576]	training's multi_logloss: 0.304783
# [1577]	training's multi_logloss: 0.304738
# [1578]	training's multi_logloss: 0.304616
# [1579]	training's multi_logloss: 0.304568
# [1580]	training's multi_logloss: 0.304519
# [1581]	training's multi_logloss: 0.304475
# [1582]	training's multi_logloss: 0.304431
# [1583]	training's multi_logloss: 0.304378
# [1584]	training's multi_logloss: 0.304301
# [1585]	training's multi_logloss: 0.304251
# [1586]	training's multi_logloss: 0.304189
# [1587]	training's multi_logloss: 0.304132
# [1588]	training's multi_logloss: 0.304089
# [1589]	training's multi_logloss: 0.304041
# [1590]	training's multi_logloss: 0.303976
# [1591]	training's multi_logloss: 0.303936
# [1592]	training's multi_logloss: 0.303894
# [1593]	training's multi_logloss: 0.303844
# [1594]	training's multi_logloss: 0.303722
# [1595]	training's multi_logloss: 0.30367
# [1596]	training's multi_logloss: 0.303617
# [1597]	training's multi_logloss: 0.303561
# [1598]	training's multi_logloss: 0.303508
# [1599]	training's multi_logloss: 0.303444
# [1600]	training's multi_logloss: 0.303392
# LGBMClassifier(learning_rate=0.15, max_depth=None, n_estimators=1600)

# %%
clf_pred = clf.predict(X_test)
f1_score(y_test, clf_pred, average='micro')
# Out:
# 0.741044876345427

# %% [markdown]
# ### Da peor balanceando los pesos.

# %%
test_values = pd.read_csv('../../csv/test_values.csv', index_col = "building_id")

# %%
test_values_subset = test_values
test_values_subset["geo_level_1_id"] = test_values_subset["geo_level_1_id"].astype("category")

# %%
def encode_and_bind(original_dataframe, feature_to_encode):
    dummies = pd.get_dummies(original_dataframe[[feature_to_encode]])
    res = pd.concat([original_dataframe, dummies], axis=1)
    res = res.drop([feature_to_encode], axis=1)
    return(res) 

features_to_encode = ["geo_level_1_id", "land_surface_condition", "foundation_type", "roof_type",\
                     "position", "ground_floor_type", "other_floor_type",\
                     "plan_configuration", "legal_ownership_status"]
for feature in features_to_encode:
    test_values_subset = encode_and_bind(test_values_subset, feature)

# %%
preds = clf.predict(test_values_subset)

# %%
submission_format = pd.read_csv('../../csv/submission_format.csv', index_col = "building_id")

# %%
my_submission = pd.DataFrame(data=df,
                             columns=submission_format.columns,
                             index=submission_format.index)

# %%
df.to_csv('../../csv/predictions/LightGBM.csv')

# %%
test_values_subset['height_percentage'].value_counts().sort_index().plot(figsize= (15, 10))
# Out:
# <AxesSubplot:>

# %%
test_values_subset['area_percentage'].value_counts().sort_index().plot(figsize= (15, 10))
# Out:
# <AxesSubplot:>
