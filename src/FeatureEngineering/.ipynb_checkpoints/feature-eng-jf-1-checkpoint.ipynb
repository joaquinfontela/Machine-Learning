# %% [markdown]
# # LIGHT GBM

# %%
pip install lightgbm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.ticker as ticker
import seaborn as sns
from sklearn.datasets import load_boston
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler, Normalizer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ParameterGrid
from sklearn.inspection import permutation_importance
import multiprocessing
import lightgbm as lgb

# %%
labels = pd.read_csv('../../csv/train_labels.csv')
labels.head()
# Out:
#    building_id  damage_grade
# 0       802906             3
# 1        28830             2
# 2        94947             3
# 3       590882             2
# 4       201944             3

# %%
values = pd.read_csv('../../csv/train_values.csv')
values.T
# Out:
#                                         0      1      2       3       4       \
# building_id                             802906  28830  94947  590882  201944
# geo_level_1_id                               6      8     21      22      11
# geo_level_2_id                             487    900    363     418     131
# geo_level_3_id                           12198   2812   8973   10694    1488
# count_floors_pre_eq                          2      2      2       2       3
# age                                         30     10     10      10      30
# area_percentage                              6      8      5       6       8
# height_percentage                            5      7      5       5       9
# land_surface_condition                       t      o      t       t       t
# foundation_type                              r      r      r       r       r
# roof_type                                    n      n      n       n       n
# ...

# %%
values["building_id"].count() == values["building_id"].drop_duplicates().count()
# Out:
# True

# %%
to_be_categorized = ["land_surface_condition", "foundation_type", "roof_type",\
                     "position", "ground_floor_type", "other_floor_type",\
                     "plan_configuration", "legal_ownership_status"]
for row in to_be_categorized:
    values[row] = values[row].astype("category")

# %%
datatypes = dict(values.dtypes)
for row in values.columns:
    if datatypes[row] != "int64" and datatypes[row] != "int32" and \
       datatypes[row] != "int16" and datatypes[row] != "int8":
        continue
    if values[row].nlargest(1).item() > 32767 and values[row].nlargest(1).item() < 2**31:
        values[row] = values[row].astype(np.int32)
    elif values[row].nlargest(1).item() > 127:
        values[row] = values[row].astype(np.int16)
    else:
        values[row] = values[row].astype(np.int8)

# %%
labels["building_id"] = labels["building_id"].astype(np.int32)
labels["damage_grade"] = labels["damage_grade"].astype(np.int8)

# %%
values['age'].value_counts().sort_values(ascending=False).plot(kind='bar', figsize=(15,15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Podemos observar dos cosas:
# ### - Por un lado, que los valores despues del 100 son mucho menos frecuentes.
# ### - Por el otro, que luego de 200, el unico valor que se presenta es 995.

# %%
values['age_is_leq_than_100'] = (values['age'] <= 100).astype(np.int8)
values['age_is_greater_than_200'] = (values['age'] > 200).astype(np.int8)
values['families_per_area'] = values['count_families'] / values['area_percentage']
values
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0            802906               6             487           12198
# 1             28830               8             900            2812
# 2             94947              21             363            8973
# 3            590882              22             418           10694
# 4            201944              11             131            1488
# ...             ...             ...             ...             ...
# 260596       688636              25            1335            1621
# 260597       669485              17             715            2060
# 260598       602512              17              51            8163
# 260599       151409              26              39            1851
# 260600       747594              21               9            9101
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                         2   30                6                  5
# ...

# %%
corr_matrix = values.corr()
fig, ax = plt.subplots(figsize=(25,25))         # Sample figsize in inches
sns.heatmap(corr_matrix, 
        xticklabels=corr_matrix.columns,
        yticklabels=corr_matrix.columns,
        ax=ax,
        annot=True)
# Out:
# <AxesSubplot:>

# %%
important_values = values\
                .merge(labels, on="building_id")
important_values.drop(columns=["building_id"], inplace = True)
important_values["geo_level_1_id"] = important_values["geo_level_1_id"].astype("category")

# %%
important_values[important_values['has_superstructure_cement_mortar_brick'] == 1].groupby('age')['damage_grade'].mean()\
    .plot(kind='bar', figsize=(15, 10))
# Out:
# <AxesSubplot:xlabel='age'>

# %%
important_values[important_values['has_superstructure_bamboo'] == 1].groupby('age')['damage_grade'].mean()\
    .plot(kind='bar', figsize=(15, 10))
# Out:
# <AxesSubplot:xlabel='age'>

# %%
important_values[important_values['has_superstructure_rc_engineered'] == 1].groupby('age')['damage_grade'].mean()\
    .plot(kind='bar', figsize=(15, 10))
# Out:
# <AxesSubplot:xlabel='age'>

# %%
important_values[important_values['has_superstructure_rc_non_engineered'] == 1].groupby('age')['damage_grade'].mean()\
    .plot(kind='bar', figsize=(15, 10))
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# ## Parece razonable indicarle al modelo cuando:
# ##### -La superestructura es de cemento y ladrillo y la antiguedad es menor a 50 anios.
# ##### -La superestructura es de bambu y la antiguedad es menor a 25 anios.
# ##### -La superestructura es rc_engineered y la antiguedad es menor a 35 anios.
# ##### -La superestructura es rc_non_engineered y la antiguedad es menor a 30 anios.

# %%
important_values['brick_and_age_less_than_50_yrs'] =\
    ((important_values['has_superstructure_cement_mortar_brick']) & (important_values['age'] < 50)).astype(np.int8)
important_values['bamboo_and_age_less_than_25_yrs'] =\
    ((important_values['has_superstructure_bamboo']) & (important_values['age'] < 25)).astype(np.int8)
important_values['rc_engineered_and_age_less_than_35_yrs'] =\
    ((important_values['has_superstructure_rc_engineered']) & (important_values['age'] < 35)).astype(np.int8)
important_values['rc_non_engineered_and_age_less_than_30_yrs'] =\
    ((important_values['has_superstructure_rc_non_engineered']) & (important_values['age'] < 30)).astype(np.int8)
important_values
# Out:
#        geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  \
# 0                   6             487           12198                    2
# 1                   8             900            2812                    2
# 2                  21             363            8973                    2
# 3                  22             418           10694                    2
# 4                  11             131            1488                    3
# ...               ...             ...             ...                  ...
# 260596             25            1335            1621                    1
# 260597             17             715            2060                    2
# 260598             17              51            8163                    3
# 260599             26              39            1851                    2
# 260600             21               9            9101                    3
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(important_values.drop(columns = 'damage_grade'),
                                                    important_values['damage_grade'], test_size = 0.2, random_state = 123)

# %% [markdown]
# ### Se intentaron normalizar las columnas numericas pero el resultado terminaba siendo peor de lo esperado.

# %%
# columns_to_normalize = ['age', 'count_floors_pre_eq', 'area_percentage', 'height_percentage', 'count_families']

# minmax_transformer = Pipeline(steps=[
#         ('minmax', MinMaxScaler())])

# for col in columns_to_normalize:
#     column_transformer = ColumnTransformer(remainder = 'passthrough',
#                                            transformers = [
#                                                ('mms', minmax_transformer, [col])
#                                            ])
#     X_train[col] = column_transformer.fit_transform(X_train)
#     X_train[col] = (X_train[col]).astype(float)
#     X_test[col] = column_transformer.fit_transform(X_test)
#     X_test[col] = (X_test[col]).astype(float)

# %% [markdown]
# # OneHot Encoding

# %%
def encode_and_bind(original_dataframe, feature_to_encode):
    dummies = pd.get_dummies(original_dataframe[[feature_to_encode]])
    res = pd.concat([original_dataframe, dummies], axis=1)
    res = res.drop([feature_to_encode], axis=1)
    return(res) 

features_to_encode = ["geo_level_1_id", "land_surface_condition", "foundation_type", "roof_type",\
                     "position", "ground_floor_type", "other_floor_type",\
                     "plan_configuration", "legal_ownership_status"]
for feature in features_to_encode:
    X_train = encode_and_bind(X_train, feature)
    X_test = encode_and_bind(X_test, feature)

# %%
clf = lgb.LGBMClassifier(n_estimators = 1700)
clf.fit(X_train, y_train)
# Out:
# LGBMClassifier(n_estimators=1700)

# %%
clf_pred = clf.predict(X_test)
f1_score(y_test, clf_pred, average='micro')
# Out:
# 0.7413518543389421

# %%
df = pd.DataFrame({"column": X_train.columns.to_list(), "importance": clf.feature_importances_})
df = df.sort_values("importance", ascending=False).set_index("column")
df.plot(kind='bar', figsize = (20,20), orientation='vertical')
# Out:
# <AxesSubplot:xlabel='column'>

# %%
test_values = pd.read_csv('../../csv/test_values.csv', index_col = "building_id")

# %%
test_values_subset = test_values
test_values_subset["geo_level_1_id"] = test_values_subset["geo_level_1_id"].astype("category")

# %%
preds = clf.predict(test_values_subset)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-2856c9b1ec5a> in <module>
# ----> 1 preds = clf.predict(test_values_subset)
#
# ~/.local/lib/python3.8/site-packages/lightgbm/sklearn.py in predict(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, **kwargs)
#     905                 pred_leaf=False, pred_contrib=False, **kwargs):
#     906         """Docstring is inherited from the LGBMModel."""
# --> 907         result = self.predict_proba(X, raw_score, start_iteration, num_iteration,
#     908                                     pred_leaf, pred_contrib, **kwargs)
#     909         if callable(self._objective) or raw_score or pred_leaf or pred_contrib:
#
# ~/.local/lib/python3.8/site-packages/lightgbm/sklearn.py in predict_proba(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, **kwargs)
# ...

# %%
submission_format = pd.read_csv('../../csv/submission_format.csv', index_col = "building_id")

# %%
my_submission = pd.DataFrame(data=df,
                             columns=submission_format.columns,
                             index=submission_format.index)

# %%
# df.to_csv('../../csv/predictions/LightGBM.csv')

# %%
test_values_subset['height_percentage'].value_counts().sort_index().plot(figsize= (15, 10))

# %%
test_values_subset['area_percentage'].value_counts().sort_index().plot(figsize= (15, 10))
